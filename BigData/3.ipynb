# %%
from konlpy.tag import Twitter 
from collections import Counter

# https://blog.naver.com/hsmc1985/221780279476

# %%
file = open("C:/Temp/pantone.csv", 'r')
lists = file.readlines() 
file.close() 
lists
# Out:
# ['2000 Cerulean Blue\n',
#  '\n',
#  '“스트레스를 많이 받는 첨단 기술 시대에 우리는 위안을 찾을 것이고 세룰란 블루는 완벽한 진정 효과를 낼 것이다.”\n',
#  '\n',
#  '"첫해에, 팬톤은 그들이 ‘밀레니엄 컬러’라고 불렀던 세룰란 블루와 함께 올해의 컬러 선정을 시작했습니다. 전 이들은 소비자들이 새롭게 맞이한 밀레니엄 시대에 내면의 평화와 성취를 추구함과 동시에 과거를 반성하고 미래를 바라보고 있다고 생각했습니다. 그래서 그들은 하늘을 연상시키는 고요한 파란색 음영을 선택했습니다."\n',
#  '\n',
#  '2001 Fuchsia Rose\n',
#  '\n',
#  '세룰란과 거의 정반대라는 점 때문에 퓨시아 로즈가 선택되지 않았나 생각합니다.\n',
#  '전년도와는 반대로 여성스럽고 섹시한 컬러가 선택되었습니다. Fuchsia Rose는 2001년에 웹 디자인과 실내 디자인에서 인기 있는 색상이었습니다.\n',
#  '\n',
#  '2002 True Red\n',
#  '\n',
#  '애국적인 색채를 가진 트루레드는 9.11테러의 영향으로 선택되었습니다.\n',
#  '소방차나 심장 같은 빨간색은 연민과 사랑을 상징합니다. 9/11 테러 공격으로부터 국가가 천천히 회복되면서 팬톤은 의미 있고 애국적인 색상으로 True Red를 선택했습니다.\n',
#  '색상을 통해 그 시대의 분위기와 상황을 조금이나마 유추해볼 수 있다는 점 또한 올해의 컬러가 기다려지는 이유 중 하나이지 않을까 생각합니다.\n',
#  '\n',
#  '2003 Aqua Sky\n',
#  '\n',
#  '희망과 평온을 되찾기 위해 시원한 파란색이 선택되었습니다. 아쿠아 스카이는 타 파란색에 비해 좀 더 차분하고 시원합니다.\n',
#  '이 색상은 당시 여성의 패션과 가구 디자인에서 많이 활용되었다고 합니다.\n',
#  '\n',
#  '2004 Tiger Lily\n',
#  '\n',
#  '타이거 릴리는 밝고 이국적인 느낌을 가지고 있습니다. 팬톤은 그 멋진 요소를 활용하고자 했습니다.\n',
#  '"그 해 일어난 유럽연합의 대규모 확장, 2004년 하계 올림픽, 그리고 쓰나미로 인해 발생된 남아시아 희생자들에 대한 전 세계인의 안타까움과 도움의 손길을 타이거 릴리에 담아내려고 했습니다."\n',
#  '\n',
#  '2005 Blue Turquoise\n',
#  '\n',
#  '"올해의 컬러를 선정할 때 팬톤은 자연의 색상에서 많은 영감을 받았습니다. 2004년 타이거 릴리의 자연(오렌지)에 이어, 블루 터키시스는 2005년 올해의 색상으로 선정되었습니다."\n',
#  '이 잔잔한 파란색은 바다의 색이며 미국 남서부의 태피스트리나 다른 예술품에도 자주 사용되었습니다. 블루 터키시스는 초록색이 적고 좀 더 시원한 느낌을 준다는 점에서 청록색과는 조금 다릅니다.\n',
#  '\n',
#  '2006 Sand dollar\n',
#  '\n',
#  '팬톤은 다가올 금융위기를 예견했던 것일까요?\n',
#  '\n',
#  '"2006년에 서브프라임 모기지 위기는 금융위기의 세계적인 연쇄 반응을 촉발시켰습니다. 보통 올해의 색상이 밝은 반면, 경제에 대한 우려를 나타내기 위해 중립적인 샌드 달러(Sand Dollar)가 선택되었습니다."\n',
#  '사막과 다른 야외 환경을 상기시키는 것은 브랜드에 대한 자연스럽고 유기적인 느낌을 표현하고자 하는 인테리어 디자인과 그래픽 디자이너들에게 각광받는 컬러였습니다.\n',
#  '\n',
#  '2007 Chili Pepper\n',
#  '\n',
#  '2007년에는 다양한 문화적 영향이 혼합되어 나타나던 시기입니다.\n',
#  '\n',
#  '칠리 페퍼는 색상뿐만 아니라 이름에서부터 이국적인 취향을 반영하고 있습니다.\n',
#  '"팬톤 컬러연구소의 리트리스 아이즈먼(Leatrice Eiseman) 연수소장은 “ 빨간색만큼 모험정신을 반영하는 것은 없다. 동시에, 칠리 페퍼는 어느 정도의 자신감과 맛을 말한다. 당신의 옷장과 생활 공간에 이 색상을 포함시키면 극적인 연출과 흥분을 더 하게 될 것이다.” 라고 설명했습니다."\n',
#  '\n',
#  '2008 Blue Iris\n',
#  '\n',
#  '신뢰성과 마법을 나타내는 파란색과 보라색 혼합\n',
#  '\n',
#  '"“파란색의 안정되고 평온한 면과 보라색의 신비롭고 영적인 특징을 결합한 블루 아이리스는 복잡한 세계에서 안심할 수 있는 필요를 충족시키면서 약간의 미스터리와 흥분을 더 했다. 우리는 Blue Iris를 올해의 색상으로 선택했는데, 이는 패션, 화장품, 가정용 제품의 색상 방향을 가장 잘 나타낸 것이다.”라고 리트리스 아이즈먼(Leatrice Eiseman) 연수소장은 설명했습니다."\n',
#  '\n',
#  '2009 Mimosa\n',
#  '\n',
#  '"“노란색은 태양의 따뜻함과 보살핌을 보여주는 것으로, 우리가 인간으로서 안심시키기 위해 끌리는 본능입니다.”"\n',
#  '\n',
#  '2009년 ‘미모사’라는 이름의 노란색 톤이 올해의 컬러로 선정되었습니다. 경제적 불확실성과 정치적 변화의 시기임을 고려해 볼 때 팬톤은 행복한 낙관주의가 필요하다는 것을 느꼈고 노란색보다 희망과 확신을 더 잘 표현할 수 있는 색상은 없다고 말했습니다.\n',
#  '미모사는 다른 색상과 조화를 이루며 남성과 여성에게 어필할 뿐만 아니라 패션과 인테리어 분야에서도 많은 인기를 끌었습니다.\n',
#  '\n',
#  '2010 Turquoise\n',
#  '\n',
#  '"“비록 그것이 환상일지라도, 즐겁고 매력적인 열대 낙원으로 데려간다.”"\n',
#  '\n',
#  '청색의 평온함과 녹색 기운을 결합한 터키석은 위로와 안락함을 불러일으킴과 동시에 소비자들의 웰빙 감각을 회복시켰습니다.\n',
#  '터키석은 열대 지방의 물과 여유로운 휴가를 연상시키며 스트레스 없는 기분을 느끼게 해줍니다.\n',
#  '"또한, 많은 문화권에서 터키석은 깊은 연민과 치유의 색, 믿음과 진실의 색이라고 인식되어있습니다."\n',
#  '"2008년 세계 경제 상황은 회복되지 않았고, 사람들이 절실히 필요로 하는 휴식을 주고자 했던 팬톤의 Turquoise는 어쩌면 당연한 선택이었는지도 모릅니다."\n',
#  '\n',
#  '2011 Honeysuckle\n',
#  '\n',
#  '"“스트레스를 받을 때는 기분을 좋게 해줄 무언가가 필요합니다. Honeysuckle은 매력적이고 자극적인 색상으로, 우울증을 피할 수 있는 완벽한 색입니다.”"\n',
#  '\n',
#  '팬톤은 당시 소비자들의 활력을 끌어올리고 자신감과 열정을 주고자 했습니다. 그 때문에 고무적이고 고양적인 핑크색 ‘허니슈클’은 자연스럽게 팬톤의 선택을 받게 되었습니다.\n',
#  '"2010년의 컬러인 터키석이 많은 사람들에게 스트레스로부터 탈출의 역할을 했다면, 허니슈클은 소비자들에게 일상의 활기를 주는 역할을 했습니다."\n',
#  '"특히 당시, 어느 결혼식에서나 볼 수 있을 만큼 웨딩드레스에서 많은 인기를 끌었던 색상입니다."\n',
#  '\n',
#  '2012 Tangerine Tango\n',
#  '\n',
#  '“이 활기차고 매력적인 오렌지와 함께 새해를 맞이하세요.”\n',
#  '\n',
#  '팬톤은 세상을 좀 깨워야 한다고 생각했습니다. 그래서 그들은 2012년 컬러로 일몰을 연상시키는 오렌지 색상을 선택했습니다.\n',
#  '리트리스 아이즈먼(Leatrice Eiseman) 연구소장은 “단순하면서도 매력적인 Tangerine Tango는 깊이 있는 오렌지다.”라고 말했습니다.\n',
#  '또한 “Tangerine Tango는 일몰의 빛나는 그늘을 기억하며 붉은색의 생기 넘치는 아드레날린 그리고 노란색의 온기와 결합해 뜨거운 열정을 나타낸다.”라고 덧붙였습니다.\n',
#  '"색깔 이론에 따르면, 오렌지는 창조의 색이며 창의적인 사고를 자극한다고 합니다. 그것은 많은 혁신가들과 창의적인 사람들이 왜 그렇게 오렌지 컬러를 좋아하는지를 설명해 줍니다."\n',
#  '\n',
#  '2013 Emerald Green\n',
#  '\n',
#  '“우아하고 아름다운 컬러.”\n',
#  '\n',
#  '"에메랄드 그린은 우리의 행복, 균형, 조화에 대한 감각을 향상시킵니다.? 2013년의 컬러는 지난해에 비해 많이 원숙해졌다는 느낌이 듭니다."\n',
#  '"온화한 분위기를 내는 대신, 깊은 보석 톤이 우리의 행복감을 높이고 균형을 증진시킬 것이라는 것이라고 팬톤은 설명했습니다."\n',
#  '\n',
#  '2014 Radiant Orchid\n',
#  '\n',
#  '"“Radiant Orchid는 자신감을 불어넣고 큰 기쁨, 사랑 그리고 건강을 배출합니다. 그것은 매혹적인 자주색이며, 고혹적인 매력으로 여러분을 끌어들일 것입니다.”"\n',
#  '\n',
#  '팬톤은 이 핑크빛 꽃잎이 따뜻함과 기쁨 그리고 창의력을 불러일으킨다고 생각해 선택했습니다.\n',
#  '"보라색과 분홍색이라는 두 조합은 독창성과 창의성을 장려하는데, 이것은 놀라운 기술 발달과 소규모 사업 성공의 지속적인 증가를 나타낸 당시 미국의 상황을 반영했다는 생각이 듭니다."\n',
#  '\n',
#  '2015 Marsala\n',
#  '\n',
#  '“마살라는 우리를 따뜻한 곳으로 끌어들이는 미묘하게 매력적인 색상이다.”\n',
#  '\n',
#  '"훌륭한 와인처럼, 마살라는 자연적으로 튼튼하고 토양이 많은 붉은 포도주로, 우리의 마음, 몸, 영혼을 윤택하게 할 색상이라고 합니다."\n',
#  '"마살라는 보살핌과 성취감을 주는 부엌과 식당, 집안 곳곳의 테이블, 소형 가전제품, 라인 등에 이상적인 색상으로 사용되었으며 활기차지만 세련된 톤이라는 평가를 받고 있습니다."\n',
#  '\n',
#  '2016 Rose Quartz and Serenity\n',
#  '\n',
#  '최초의 두 가지 색상 혼합 ? 로즈 쿼즈와 세레니티\n',
#  '\n',
#  '"사상 처음으로 팬톤은 두 가지 색상을 선택했습니다. 먼저 첫 번째는 따뜻하고 부드러운 핑크색 ‘Rose Quartz’였는데, 이는 밀리언 핑크색 열풍과 관련이 있었습니다."\n',
#  '로즈쿼즈는 두 번째 색상인 ’Serenity’ 와 조화를 이루게 됩니다. 이 두 가지의 색상은 심리적으로 안정을 찾고 싶어 하는 현대인들을 충족시켜주는 안락한 색상입니다.\n',
#  '또한 팬톤은 패션과 색체에 대한 성적 고정관념이 점차 모호해지는 것을 전 세계 곳곳에서 경험하고 있었으며 앞으로도 모든 분야의 디자인에 큰 영향을 줄 것이라고 생각했습니다.\n',
#  '\n',
#  '이렇듯 팬톤의 상징적인 컬러 선정은 우리의 문화 속에서 발생한 것들에 대한 감정 표현과 관점에 대해 전달하고 있음을 알 수 있습니다.\n',
#  '"로즈 쿼츠컬러가 설득력 있고 부드러운 톤으로서 동정과 평정의 느낌을 전달하고 있다면, 세레니티는 머리 위에 넓게 펼쳐진 푸른 하늘이 주는 고요함, 화창함, 청명, 침착을 의미하며 기분전환과 휴식의 느낌을 전달하고 있습니다."\n',
#  '\n',
#  '2017 Greenery\n',
#  '\n',
#  '"상쾌하고 활기를 띠는 그늘, 그리너리는 ‘새로운 시작’을 상징합니다."\n',
#  '\n',
#  '리트리스 아이즈먼(Leatrice Eiseman)은 “현대인들은 스트레스받고 긴장된 일상을 보내고 있다.”라며 그리너리는 현대의 삶을 더 깊이 살아갈수록 자연의 아름다움과 그것에 대한 현대인들의 갈망을 반영한 것이라 설명했습니다.\n',
#  '"이러한 그리너리 색상은 싱그러운 옐로 그린의 컬러로 자연 그대로의 녹색 채소들, 푸른 녹음이 숨을 쉬는 색으로 보는 사람들로 하여금 자연 속을 거니는 듯한 생동감 넘치는 모습을 자아냅니다."\n',
#  '또한 삶을 활기차게 하는 그늘인 녹색은 개인적 열정과 활력을 추구하는 것을 상징합니다.\n',
#  '\n',
#  '2018 Ultra Violet\n',
#  '\n',
#  '“무궁무진한 밤하늘을 떠올리게 하며 가능성의 상징이자 현시대를 넘어서려는 열망을 불러일으키는 색.”\n',
#  '\n',
#  '"팬톤 컬러 연구소의 리트리스 아이즈먼(Leatrice Eiseman)은 “우리는 상상력과 창의력이 필요한 시대를 살고 있다.”며 창조적인 영감을 불러일으키고 우리의 지각 능력과 잠재력을 끌어올릴 수 있는 색상으로 울트라 바이올렛을 대신할 색상이 없다고 설명했습니다. 매우 도발적이고 신비로운 색상인 Ultra Violet은 독창성 그리고 미래를 향한 선견지명을 표현하고 있습니다. 이미 여러 패션, 인테리어 등 각종 브랜드에서 보라색이 적용된 아이템들을 쉽게 볼 수 있습니다."\n',
#  '\n',
#  '이렇듯 2000년부터 시작된 올해의 컬러를 살펴보며 저 또한 정리가 되고 몰랐던 사실을 알게 되기도 했습니다.? 단순히 심미적인 이유가 아니라 당시의 이슈나 라이프 스타일을 반영한 색상이기에 팬톤의 컬러는 좀 더 특별하지 않을까 생각합니다.\n',
#  '때문에 얼마 남지 않은 2019 올해의 컬러가 더 기대되는 것 아닐까요?\n']

# %%
twitter = Twitter() 
morphs = [] 
for sentence in lists:
    morphs.append(twitter.pos(sentence)) 
print(morphs)
# Out:
# C:\Users\KYN\anaconda3\envs\pydatavenv\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [[('2000', 'Number'), ('Cerulean', 'Alpha'), ('Blue', 'Alpha'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('“', 'Foreign'), ('스트레스', 'Noun'), ('를', 'Josa'), ('많이', 'Adverb'), ('받는', 'Verb'), ('첨단', 'Noun'), ('기술', 'Noun'), ('시대', 'Noun'), ('에', 'Josa'), ('우리', 'Noun'), ('는', 'Josa'), ('위안', 'Noun'), ('을', 'Josa'), ('찾을', 'Verb'), ('것', 'Noun'), ('이고', 'Josa'), ('세', 'Modifier'), ('룰란', 'Noun'), ('블루', 'Noun'), ('는', 'Josa'), ('완벽한', 'Adjective'), ('진정', 'Noun'), ('효과', 'Noun'), ('를', 'Josa'), ('낼', 'Noun'), ('것', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation'), ('”', 'Foreign'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('"', 'Punctuation'), ('첫', 'Noun'), ('해에', 'Verb'), (',', 'Punctuation'), ('팬톤', 'Noun'), ('은', 'Josa'), ('그', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('‘', 'Foreign'), ('밀레니엄', 'Noun'), ('컬러', 'Noun'), ('’', 'Punctuation'), ('라고', 'Josa'), ('불렀던', 'Verb'), ('세', 'Modifier'), ('룰란', 'Noun'), ('블루', 'Noun'), ('와', 'Josa'), ('함께', 'Adverb'), ('올해', 'Noun'), ('의', 'Josa'), ('컬러', 'Noun'), ('선정', 'Noun'), ('을', 'Josa'), ('시작', 'Noun'), ('했습니다', 'Verb'), ('.', 'Punctuation'), ('전', 'Noun'), ('이', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('소비자', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('새롭게', 'Adjective'), ('맞이', 'Noun'), ('한', 'Josa'), ('밀레니엄', 'Noun'), ('시대', 'Noun'), ('에', 'Josa'), ('내면', 'Noun'), ('의', 'Josa'), ('평화', 'Noun'), ('와', 'Josa'), ('성취', 'Noun'), ('를', 'Josa'), ('추구', 'Noun'), ('함', 'Noun'), ('과', 'Josa'), ('동시', 'Noun'), ('에', 'Josa'), ('과거', 'Noun'), ('를', 'Josa'), ('반성', 'Noun'), ('하고', 'Josa'), ('미래', 'Noun'), ('를', 'Josa'), ('바라보고', 'Verb'), ('있다고', 'Adjective'), ('생각', 'Noun'), ('했습니다', 'Verb'), ('.', 'Punctuation'), ('그래서', 'Adverb'), ('그', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('하늘', 'Noun'), ('을', 'Josa'), ('연상', 'Noun'), ('시키는', 'Verb'), ('고요한', 'Noun'), ('파란색', 'Noun'), ('음영', 'Noun'), ('을', 'Josa'), ('선택', 'Noun'), ('했습니다', 'Verb'), ('."', 'Punctuation'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('2001', 'Number'), ('Fuchsia', 'Alpha'), ('Rose', 'Alpha'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('세', 'Modifier'), ('룰란', 'Noun'), ('과', 'Josa'), ('거의', 'Noun'), ('정반대', 'Noun'), ('라는', 'Josa'), ('점', 'Noun'), ('때문', 'Noun'), ('에', 'Josa'), ('퓨시', 'Noun'), ('아', 'Josa'), ('로즈', 'Noun'), ('가', 'Josa'), ('선택', 'Noun'), ('되지', 'Verb'), ('않았나', 'Verb'), ('생각', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')], [('전', 'Modifier'), ('년도', 'Noun'), ('와는', 'Josa'), ('반대', 'Noun'), ('로', 'Josa'), ('여성', 'Noun'), ('스럽고', 'Adjective'), ('섹시한', 'Adjective'), ('컬러', 'Noun'), ('가', 'Josa'), ('선택', 'Noun'), ('되었습니다', 'Verb'), ('.', 'Punctuation'), ('Fuchsia', 'Alpha'), ('Rose', 'Alpha'), ('는', 'Verb'), ('2001년', 'Number'), ('에', 'Foreign'), ('웹', 'Noun'), ('디자인', 'Noun'), ('과', 'Josa'), ('실내', 'Noun'), ('디자인', 'Noun'), ('에서', 'Josa'), ('인기', 'Noun'), ('있는', 'Adjective'), ('색상', 'Noun'), ('이었습니다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('2002', 'Number'), ('True', 'Alpha'), ('Red', 'Alpha'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('애국', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('색채', 'Noun'), ('를', 'Josa'), ('가진', 'Verb'), ('트루', 'Noun'), ('레드', 'Noun'), ('는', 'Josa'), ('9.11', 'Number'), ('테러', 'Noun'), ('의', 'Josa'), ('영향', 'Noun'), ('으로', 'Josa'), ('선택', 'Noun'), ('되었습니다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')], [('소방차', 'Noun'), ('나', 'Josa'), ('심장', 'Noun'), ('같은', 'Adjective'), ('빨간색', 'Noun'), ('은', 'Josa'), ('연민', 'Noun'), ('과', 'Josa'), ('사랑', 'Noun'), ('을', 'Josa'), ('상징', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('9/11', 'Number'), ('테러', 'Noun'), ('공격', 'Noun'), ('으로부터', 'Josa'), ('국가', 'Noun'), ('가', 'Josa'), ('천천히', 'Adverb'), ('회복', 'Noun'), ('되면서', 'Verb'), ('팬톤', 'Noun'), ('은', 'Josa'), ('의미', 'Noun'), ('있고', 'Adjective'), ('애국', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('색상', 'Noun'), ('으로', 'Josa'), ('True', 'Alpha'), ('Red', 'Alpha'), ('를', 'Noun'), ('선택', 'Noun'), ('했습니다', 'Verb'), ('.', 'Punctuation'), ('\n', ' ...

# %%
noun_adj_adv_list=[] 
for sentence in morphs : 
    for word, tag in sentence : 
        if tag in ['Noun'] and ("것" not in word) and ("내" not in word)and ("나" not in word)and ("수"not in word) and("게"not in word)and("말"not in word): 
            noun_adj_adv_list.append(word) 

print(noun_adj_adv_list)
# Out:
# ['스트레스', '첨단', '기술', '시대', '우리', '위안', '룰란', '블루', '진정', '효과', '낼', '첫', '팬톤', '그', '밀레니엄', '컬러', '룰란', '블루', '올해', '컬러', '선정', '시작', '전', '이', '소비자', '맞이', '밀레니엄', '시대', '평화', '성취', '추구', '함', '동시', '과거', '반성', '미래', '생각', '그', '하늘', '연상', '고요한', '파란색', '음영', '선택', '룰란', '거의', '정반대', '점', '때문', '퓨시', '로즈', '선택', '생각', '년도', '반대', '여성', '컬러', '선택', '웹', '디자인', '디자인', '인기', '색상', '애국', '색채', '트루', '레드', '테러', '영향', '선택', '소방차', '심장', '빨간색', '연민', '사랑', '상징', '테러', '공격', '국가', '회복', '팬톤', '의미', '애국', '색상', '를', '선택', '색상', '통해', '그', '시대', '분위기', '상황', '조금', '유추', '점', '또한', '올해', '컬러', '이유', '중', '생각', '희망', '평온', '위해', '파란색', '선택', '아쿠아', '스카이', '타', '파란색', '좀', '더', '이', '색상', '당시', '여성', '패션', '가구', '디자인', '활용', '타이거', '릴리', '국적', '느낌', '가지', '팬톤', '그', '요소', '활용', '그', '해', '유럽연합', '대규모', '확장', '계', '올림픽', '발생', '남아시아', '희생', '자', '대한', '전', '세계', '움', '도움', '손길', '타이거', '릴리', '올해', '컬러', '선정', '때', '팬톤', '자연', '색상', '영감', '타이거', '릴리', '자연', '오렌지', '블루', '터키', '시스', '올해', '색상', '선정', '이', '파란색', '바다', '색', '미국', '남서', '부의', '태피스트리', '다른', '예술', '품', '자주', '사용', '블루', '터키', '시스', '초록색', '좀', '더', '느낌', '점', '청록색', '조금', '팬톤', '금융위기', '예견', '요', '서브프라임', '모기지', '위기', '금융위기', '세계', '연쇄', '반응', '촉발', '보통', '올해', '색상', '반면', '경제', '대한', '우려', '위해', '중립', '샌드', '달러', '선택', '사막', '다른', '야외', '환경', '상기', '브랜드', '대한', '유기', '느낌', '표현', '인테리어', '디자인', '그래픽', '디자이너', '각광', '컬러', '문화', '영향', '혼합', '시기', '칠리', '페퍼', '색상', '이름', '국적', '취향', '반영', '팬톤', '컬러', '연구소', '리트', '리스', '아이즈', '소장', '빨간색', '모험', '정신', '반영', '동시', '칠리', '페퍼', '정도', '자신감', '맛', '당신', '옷장', '생활', '공간', '이', '색상', '포함', '극적', '연출', '흥분', '더', '설명', '신뢰', '성과', '마법', '파란색', '보라색', '혼합', '파란색', '안정', '면', '보라색', '신비', '영적', '특징', '결합', '블루', '아이리스', '세계', '필요', '충족', '약간', '미스터리', '흥분', '더', '우리', '를', '올해', '색상', '선택', '패션', '화장품', '가정', '용', '제품', '색상', '방향', '가장', '리트', '리스', '아이즈', '소장', '설명', '노란색', '태양', '우리', '인간', '안심', '위해', '본능', '미모사', '이름', '노란색', '톤', '올해', '컬러', '선정', '경제', '불확실', '성과', '정치', '변화', '임', '고려', '볼', '때', '팬톤', '낙관', '주의', '노란색', '희망', '확신', '더', '표현', '색상', '미모사', '다른', '색상', '조화', '남성', '여성', '어필', '뿐', '패션', '인테리어', '분야', '인기', '비록', '환상', '일지', '매력', '열대', '낙원', '청색', '녹색', '기운', '결합', '터키석', '위로', '동시', '소비자', '웰빙', '감각', '회복', '터키석', '열대', '지방', '물', '여유', '휴가', '연상', '스트레스', '기분', '또한', '문화', '터키석', '연민', '치유', '색', '믿음', '진실', '색', '인식', '세계', '경제', '상황', '회복', '사람', '절실', '필요', '휴식', '고자', '팬톤', '어쩌면', '선택', '스트레스', '때', '기분', '무언가', '은', '매력', '자극', '색상', '우울증', '피', '색', '팬톤', '당시', '소비자', '활', '자신감', '열정', '고자', '그', '때문', '무적', '고양', '핑크색', '니슈', '은', '자연', '팬톤', '선택', '컬러', '터키석', '사람', '스트레스', '로부터', '탈출', '역할', '니슈', '소비자', '일상', '활기', '역할', '당시', '결혼식', '볼', '만큼', '웨딩드레스', '인기', '색상', '이', '매력', '오렌지', '새해', '맞이', '팬톤', '세상', '좀', '생각', '그', '컬러', '일몰', '연상', '오렌지', '색상', '선택', '리트', '리스', '아이즈', '연구소장', '매력', '깊이', '오렌지', '또한', '일몰', '그늘', '기억', '은색', '생기', '아드레날린', '노란색', '온기', '결', '열정', '색깔', '이론', '오렌지', '창조', '색', '창의', '사고', '자극', '고', '혁신', '창의', '사람', '왜', '오렌지', '컬러', '설명', '컬러', '에메랄드', '그린', '우리', '행복', '균형', '조화', '대한', '감각', '향상', '컬러', '지난해', '느낌', '듭니', '분위기', '대신', '보석', '톤', '우리', '행복감', '높이', '균형', '증진', '팬톤', '설명', '자신감', '불어', '기쁨', '사랑', '건강', '배출', '매혹', '자주색', '혹', '매력', '여러분', '팬톤', '이', '핑크', '빛', '꽃잎', '기쁨', '창의력', '생각', '선택', '보라색', '분홍색', '두', '조합', '독창', '성과', '창의성', '장려', '기술', '발달', '소규모', '사업', '성공', '지속', '증가', '당시', '미국', '상황', '반영', '생각', '듭니', '마살라', '우리', '곳', '매력', '색상', '와인', '마살라', '자연', '토양', '포도주', '우리', '마음', '몸', '영혼', '윤택', '색상', '마살라', '성취', '감', '부엌', '식당', '집안', '곳곳', '테이블', '소형', '가전제품', '라인', '등', '이상', '색상', '사용', '톤', '평가', '최초', '두', '가지', '색상', '혼합', '로', '쿼즈', '세레', '티', '사상', '처음', '팬톤', '두', '가지', '색상', '선택', '먼저', '첫', '번', '핑크색', '밀', '리언', '핑크색', '열풍', '관련', '로즈쿼즈', '두', '색상', '조화', '이', '두', '가지', '색상', '심리', '안정', '현대인', '충족', '색상', '또한', '팬톤', '패션', '색체', '대한', '성적', '고정관념', '점차', '전', '세계', '곳곳', '경험', '앞', '모든', '분야', '디자인', '영향', '줄', '생각', '팬톤', '상징', '컬러', ' ...

# %%
count = Counter(noun_adj_adv_list)
words = dict(count.most_common())
words
# Out:
# {'색상': 29,
#  '컬러': 20,
#  '팬톤': 18,
#  '선택': 13,
#  '우리': 10,
#  '올해': 9,
#  '생각': 8,
#  '더': 8,
#  '그': 7,
#  '이': 7,
#  '대한': 7,
#  '자연': 7,
#  '색': 7,
#  '파란색': 6,
#  '또한': 6,
#  '느낌': 6,
#  '오렌지': 6,
#  '설명': 6,
#  '매력': 6,
#  '스트레스': 5,
#  '시대': 5,
#  '블루': 5,
#  '선정': 5,
#  '디자인': 5,
#  '상징': 5,
#  '당시': 5,
#  '패션': 5,
#  '세계': 5,
#  '반영': 5,
#  '리트': 5,
#  '리스': 5,
#  '아이즈': 5,
#  '은': 5,
#  '두': 5,
#  '소비자': 4,
#  '좀': 4,
#  '가지': 4,
#  '표현': 4,
#  '보라색': 4,
#  '노란색': 4,
#  '톤': 4,
#  '터키석': 4,
#  '사람': 4,
#  '룰란': 3,
#  '시작': 3,
#  '전': 3,
#  '동시': 3,
#  '연상': 3,
#  '점': 3,
#  '때문': 3,
#  '여성': 3,
#  '인기': 3,
#  '영향': 3,
#  '회복': 3,
#  '상황': 3,
#  '위해': 3,
#  '타이거': 3,
#  '릴리': 3,
#  '때': 3,
#  '다른': 3,
#  '경제': 3,
#  '인테리어': 3,
#  '문화': 3,
#  '혼합': 3,
#  '자신감': 3,
#  '성과': 3,
#  '볼': 3,
#  '조화': 3,
#  '녹색': 3,
#  '기분': 3,
#  '열정': 3,
#  '핑크색': 3,
#  '그늘': 3,
#  '마살라': 3,
#  '현대인': 3,
#  '전달': 3,
#  '너리': 3,
#  '기술': 2,
#  '첫': 2,
#  '밀레니엄': 2,
#  '맞이': 2,
#  '성취': 2,
#  '추구': 2,
#  '미래': 2,
#  '하늘': 2,
#  '애국': 2,
#  '테러': 2,
#  '빨간색': 2,
#  '연민': 2,
#  '사랑': 2,
#  '의미': 2,
#  '를': 2,
#  '분위기': 2,
#  '조금': 2,
#  '이유': 2,
#  '희망': 2,
#  '활용': 2,
#  '국적': 2,
#  '발생': 2,
#  '움': 2,
#  '영감': 2,
#  '터키': 2,
#  '시스': 2,
#  '미국': 2,
#  '사용': 2,
#  '금융위기': 2,
#  '요': 2,
#  '브랜드': 2,
#  '칠리': 2,
#  '페퍼': 2,
#  '이름': 2,
#  '연구소': 2,
#  '소장': 2,
#  '흥분': 2,
#  '안정': 2,
#  '결합': 2,
#  '필요': 2,
#  '충족': 2,
#  '미모사': 2,
#  '분야': 2,
#  '열대': 2,
#  '감각': 2,
#  '휴식': 2,
#  '고자': 2,
#  '자극': 2,
#  '활': 2,
#  '니슈': 2,
#  '역할': 2,
#  '일상': 2,
#  '활기': 2,
#  '일몰': 2,
#  '깊이': 2,
#  '창조': 2,
#  '창의': 2,
#  '그린': 2,
#  '균형': 2,
#  '듭니': 2,
#  '대신': 2,
#  '기쁨': 2,
#  '창의력': 2,
#  '독창': 2,
#  '곳곳': 2,
#  '등': 2,
#  '로': 2,
#  '세레': 2,
#  '티': 2,
#  '속': 2,
#  '알': 2,
#  '푸른': 2,
#  '삶': 2,
#  '첨단': 1,
#  '위안': 1,
#  '진정': 1,
#  '효과': 1,
#  '낼': 1,
#  '평화': 1,
#  '함': 1,
#  '과거': 1,
#  '반성': 1,
#  '고요한': 1,
#  '음영': 1,
#  '거의': 1,
#  '정반대': 1,
#  '퓨시': 1,
#  '로즈': 1,
#  '년도': 1,
#  '반대': 1,
#  '웹': 1,
#  '색채': 1,
#  '트루': 1,
#  '레드': 1,
#  '소방차': 1,
#  '심장': 1,
#  '공격': 1,
#  '국가': 1,
#  '통해': 1,
#  '유추': 1,
#  '중': 1,
#  '평온': 1,
#  '아쿠아': 1,
#  '스카이': 1,
#  '타': 1,
#  '가구': 1,
#  '요소': 1,
#  '해': 1,
#  '유럽연합': 1,
#  '대규모': 1,
#  '확장': 1,
#  '계': 1,
#  '올림픽': 1,
#  '남아시아': 1,
#  '희생': 1,
#  '자': 1,
#  '도움': 1,
#  '손길': 1,
#  '바다': 1,
#  '남서': 1,
#  '부의': 1,
#  '태피스트리': 1,
#  '예술': 1,
#  '품': 1,
#  '자주': 1,
#  '초록색': 1,
#  '청록색': 1,
#  '예견': 1,
#  '서브프라임': 1,
#  '모기지': 1,
#  '위기': 1,
#  '연쇄': 1,
#  '반응': 1,
#  '촉발': 1,
#  '보통': 1,
#  '반면': 1,
#  '우려': 1,
#  '중립': 1,
#  '샌드': 1,
#  '달러': 1,
#  '사막': 1,
#  '야외': 1,
#  '환경': 1,
#  '상기': 1,
#  '유기': 1,
#  '그래픽': 1,
#  '디자이너': 1,
#  '각광': 1,
#  '시기': 1,
#  '취향': 1,
#  '모험': 1,
#  '정신': 1,
#  '정도': 1,
#  '맛': 1,
#  '당신': 1,
#  '옷장': 1,
#  '생활': 1,
#  '공간': 1,
#  '포함': 1,
#  '극적': 1,
#  '연출': 1,
#  '신뢰': 1,
#  '마법': 1,
#  '면': 1,
#  '신비': 1,
#  '영적': 1,
#  '특징': 1,
#  '아이리스': 1,
#  '약간': 1,
#  '미스터리': 1,
#  '화장품': 1,
#  '가정': 1,
#  '용': 1,
#  '제품': 1,
#  '방향': 1,
#  '가장': 1,
#  '태양': 1,
#  '인간': 1,
#  '안심': 1,
#  '본능': 1,
#  '불확실': 1,
#  '정치': 1,
#  '변화': 1,
#  '임': 1,
#  '고려': 1,
#  '낙관': 1,
#  '주의': 1,
#  '확신': 1,
#  '남성': 1,
#  '어필': 1,
#  '뿐': 1,
#  '비록': 1,
#  '환상': 1,
#  '일지': 1,
#  '낙원': 1,
#  '청색': 1,
#  '기운': 1,
#  '위로': 1,
#  '웰빙': 1,
#  '지방': 1,
#  '물': 1,
#  '여유': 1,
#  '휴가': 1,
#  '치유': 1,
#  '믿음': 1,
#  '진실': 1,
#  '인식': 1,
#  '절실': 1,
#  '어쩌면': 1,
#  '무언가': 1,
#  '우울증': 1,
#  '피': 1,
#  '무적': 1,
#  '고양': 1,
#  '로부터': 1,
#  '탈출': 1,
#  '결혼식': 1,
#  '만큼': 1,
#  '웨딩드레스': 1,
#  '새해': 1,
#  '세상': 1,
#  '연구소장': 1,
#  '기억': 1,
#  '은색': 1,
#  '생기': 1,
#  '아드레날린': 1,
#  '온기': 1,
#  '결': 1,
#  '색깔': 1,
#  '이론': 1,
#  '사고': 1,
#  '고': 1,
#  '혁신': 1,
#  '왜': 1,
#  '에메랄드': 1,
#  '행복': 1,
#  '향상': 1,
#  '지난해': 1,
#  '보석': 1,
#  '행복감': 1,
#  '높이': 1,
#  '증진': 1,
#  '불어': 1,
#  '건강': 1,
#  '배출': 1,
#  '매혹': 1,
#  '자주색': 1,
#  '혹': 1,
#  '여러분': 1,
#  '핑크': 1,
#  '빛': 1,
#  '꽃잎': 1,
#  '분홍색': 1,
#  '조합': 1,
#  '창의성': 1,
#  '장려': 1,
#  '발달': 1,
#  '소규모': 1,
#  '사업': 1,
#  '성공': 1,
#  '지속': 1,
#  '증가': 1,
#  '곳': 1,
#  '와인': 1,
#  '토양': 1,
#  '포도주': 1,
#  '마음': 1,
#  '몸': 1,
#  '영혼': 1,
#  '윤택': 1,
#  '감': 1,
#  '부엌': 1,
#  '식당': 1,
#  '집안': 1,
#  '테이블': 1,
#  '소형': 1,
#  '가전제품': 1,
#  '라인': 1,
#  '이상': 1,
#  '평가': 1,
#  '최초': 1,
#  '쿼즈': 1,
#  '사상': 1,
#  '처음': 1,
#  '먼저': 1,
#  '번': 1,
#  '밀': 1,
#  '리언': 1,
#  '열풍': 1,
#  '관련': 1,
#  '로즈쿼즈': 1,
#  '심리': 1,
#  '색체': 1,
#  '성적': 1,
#  '고정관념': 1,
#  '점차': 1,
#  '경험': 1,
#  '앞': 1,
#  '모든': 1,
#  '줄': 1,
#  '감정': 1,
#  '관점': 1,
#  '대해': 1,
#  '음': 1,
#  '쿼츠': 1,
#  '설득': 1,
#  '동정': 1,
#  '평정': 1,
#  '머리': 1,
#  '위': 1,
#  '고요함': 1,
#  '청명': 1,
#  '침착': 1,
#  '전환': 1,
#  '띠': 1,
#  '긴장': 1,
#  '라며': 1,
#  '현대': 1,
#  '갈망': 1,
#  '옐로': 1,
#  '그대로': 1,
#  '채소': 1,
#  '녹음': 1,
#  '숨': 1,
#  '거니': 1,
#  '듯': 1,
#  '생동감': 1,
#  '모습': 1,
#  '개인': 1,
#  '무궁무진': 1,
#  '밤하늘': 1,
#  '가능성': 1,
#  '이자': 1,
#  '열망': 1,
#  '상상력': 1,
#  '살': 1,
#  '며': 1,
#  '지각': 1,
#  '능력': 1,
#  '잠재력': 1,
#  '울트라': 1,
#  '바이올렛': 1,
#  '매우': 1,
#  '도발': 1,
#  '향': 1,
#  '선견지명': 1,
#  '여러': 1,
#  '각종': 1,
#  '적용': 1,
#  '아이템': 1,
#  '저': 1,
#  '정리': 1,
#  '사실': 1,
#  '기도': 1,
#  '심': 1,
#  '미적': 1,
#  '이슈': 1,
#  '라이프': 1,
#  '스타일': 1,
#  '이기': 1,
#  '얼마': 1,
#  '남지': 1,
#  '기대': 1}

# %%
from wordcloud import WordCloud 

import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
# %matplotlib inline

import matplotlib
from IPython.display import set_matplotlib_formats
matplotlib.rc('font',family = 'Malgun Gothic')

set_matplotlib_formats('retina')

matplotlib.rc('axes',unicode_minus = False)

# %%
wordcloud = WordCloud(font_path = 'C:/Windows/Fonts/malgun.ttf', background_color='white',colormap = "Accent_r", width=1500, height=1000).generate_from_frequencies(words) 
plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()
