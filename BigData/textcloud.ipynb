# %%
from konlpy.tag import Twitter 
from collections import Counter

# https://blog.naver.com/hsmc1985/221780279476

# %%
file = open("C:/Temp/2018.csv", 'r')
lists = file.readlines() 
file.close() 
lists
# Out:
# ['1.?세로무늬?(Vertical Stripes)\n',
#  '\n',
#  '"봄, 여름이 되면 스트라이프 패턴의 옷들을 많이 입을 텐데요."\n',
#  '심플하면서도 화려한듯한 느낌의 스트라이프!\n',
#  '2018년 올해는 세로 스트라이프가 강세라고 하네요 :)\n',
#  '\n',
#  '2. 옐로우 컬러 (Yellow)\n',
#  '"올해의 색은 \' 울트라 바이올렛\'으로 선정됐지만,?"\n',
#  '패션위크 런웨이에서는 옐로우 컬러가 눈에 많이 띄었는데요.\n',
#  '봄을 알리는 옐로우는?화사함을 돋보이기 위해?\n',
#  '매년 주목받는 컬러가 아닌가 싶어요!\n',
#  '\n',
#  '3. 트레인 (Train)\n',
#  "트레인은 '옷자락을 끌다'라는 뜻을 가지고 있는데요.\n",
#  '드레스나 옷의 뒷자락을 길게 늘어뜨려 바닥에 끌리는 옷을 말합니다!\n',
#  '길이만 길어졌을 뿐인데요 여성스러운 느낌이 물씬 나는 것 같아요 :->\n',
#  '\n',
#  '4. 프린지(Fringe)\n',
#  '"70년대 레트로와 히피 스타일이 유행하는 요즘,?"\n',
#  '보헤미안 분위기의 프린지 장식으로?개성 넘치는 패션을 완성할 수 있겠죠?\n',
#  '\n',
#  '5. 올 화이트(All White)\n',
#  '\n',
#  '"무난해 보이는 화이트는 언제나 사랑받는 컬러이지만,?"\n',
#  '"올해는 상, 하의 모두 화이트로 매치하는 올 화이트 룩이?트렌드라고 하네요 :)"\n',
#  '"다가올 여름, 트렌디한 패션으로 딱이에요!"\n',
#  '\n',
#  '6. 패니 팩(Fanny pack)\n',
#  '\n',
#  '패니 팩은 엉덩이를 뜻하는 Fanny 와 배낭을 뜻하는 Pack 의 합성어로\n',
#  '흔히들 힙색이라고 많이들 부른답니다!\n',
#  '1980~1990년대에 유행을 하던 아이템으로 유행이 돌고 돌아\n',
#  '2018년 잇백으로 돌아왔어요 :-)\n',
#  '\n',
#  '지금은 스트릿 + 댄디\n',
#  '\n',
#  '지금 2018SS 시즌에는 트렌드다 혹은 유행이다 라고 말 할수 있는 스타일은 없습니다. 시작하는 트렌드는 없지만 꺼져가는 패션 트렌드로는?살짝 변형된 스트릿 패션이 있습니다.\n',
#  '\n',
#  '"쇼미더머니로 인해 트렌드가 된 힙합 스타일의 스트릿 패션은 어떻게 보면?난해하고 자극적이었지만 지금 2018SS 시즌의?스트릿 패션은 블레이저, 슬랙스, 로퍼... 등의 댄디한 아이템을 활용한 댄디+스트릿 스타일로 변했습니다."\n',
#  '\n',
#  '이러한 스트릿 패션뿐만 아니라 열풍까지는 아니지만 잠깐 유행했었던 아메카지같은 스타일을 종종 볼 수 있는?2018SS 시즌은?아직 패션 트렌드가 확실히 정해지지 않았으며 이전에 트렌드였던 다양한 스타일들을 볼 수 있는 시즌입니다.\n',
#  '\n',
#  '앞으로는?테크웨어\n',
#  '\n',
#  '"그나마 현재 패션 트렌드로 발전 할 가능성이 보이는 스타일은 ""테크웨어""입니다. 2017FW 시즌에 잠깐 두각을 보인 스타일입니다.?지금은?테크웨어룩을 착용하기?부적합한 SS시즌이라?언급이 줄었지만?2018FW 시즌에는 충분히 트렌드로 발전할?가능성이 높은?스타일입니다."\n',
#  '\n',
#  '테크웨어는 고어텍스나 코듀라같은 첨단 소재와 캐쥬얼 스타일이 만난 패션입니다.?서양쪽에선 이미 많은 사람들에게?선호받는?스타일로 저리 잡았으며 현재 한국에서도?많은?연예인들의 테크웨어룩을 입고?방송에 출연하는?모습을 종종 볼 수 있습니다.\n',
#  '\n',
#  '아직 트렌드라고 하기에는 섣부르지만 충분히 트렌드가 될 만큼 개성있고 돋보적인 스타일입니다. 특히 스트릿 패션을 이끌었던 래퍼들이 많이 착용하는 걸로 보아선 충분히 주목할만 합니다.\n',
#  '\n',
#  '트렌드 아이템은 힙색\n',
#  '\n',
#  '"2018 시즌?트렌드 아이템은 ""크로스 바디 백""입니다. 쉬운말로는 ""힙색""이라고도 합니다. 과거에는 힙색하면?오직?수납을 위한 가방 혹은 배달부들이 돈을 보관하는 가방으로 여겨졌으며?패션과는 전혀 상관없는 디자인의 제품들이 많았습니다."\n',
#  '\n',
#  '하지만 지금은 스트릿 패션 스타일링에도?종종 사용되는 아이템으로 많은 브랜드에서 패션쪽을 겨냥한 디자인의 힙색을 발매하고 있습니다.?뿐만 아니라 힙색은 앞으로 트렌드가 될 수?있는 테크웨어 룩 코디에 필수적인 아이템이기도 합니다.\n',
#  '\n',
#  '힙색은 처음보는 아이템은 아니지만 새롭고?난해하진 않지만 개성있으며 디자인과 수납을 모두 만족시키는 2018시즌의 트렌드 아이템입니다.\n',
#  '\n',
#  '"올해의 컬러 ""퍼플"""\n',
#  '\n',
#  '"2018년도 패션계가 선정한 올해의 색상은 ""보라""입니다. 보라는?호불호가 많이 갈리는 색상이지만 그만큼 개성있고 신비로워?보이는?색상이기도 합니다.?"\n',
#  '\n',
#  '그렇다고 해서 무조건 생보라색 의류를 입어야 된다는 건 아닙니다. 보라색이 너무 부담스럽다면?연보라색의 의류도?충분히 매력적이고 트렌디하게 보입니다.?더불어 꼭 의류가?아니어도 자그마한?보라색?악세사리로 포인트를 주는것도 괜찮습니다.\n',
#  '\n',
#  '무작정 트렌드를 따라가는 것도 좋지 않지만?그렇다고 해서 트렌드를 너무 무시하는 것도 좋다고 볼 수는 없습니다. 자신만의 스타일에 트렌드를 더하는 것이 베스트 패션입니다.\n',
#  '\n',
#  '"2017년 F/W 컬렉션의 \'잇 아이템\'이었던 베레모는 2018년에도 유행할 전망이다. 귀엽고, 가벼우며 어떤 옷이든 쉽게 매치할 수도 있다."\n',
#  '\n',
#  '2. 울트라 바이올렛\n',
#  '"울트라 바이올렛은 팬톤이 선정한 2018년 올해의 컬러다. 재작년의 세레니티와 로즈쿼츠, 그리고 작년의 그리너리가 그랬듯 울트라 바이올렛 역시 내년 패션계를 휩쓸 것으로 예상된다."\n',
#  '"스테이트먼트 주얼리는 이미 2017년에 유행했지만, 2018년에도 그 유행이 이어질 것으로 보인다. 사이즈가 큰 링 귀걸이부터 독특한 모양의 귀걸이까지, 크기만 크다면 뭐든 유행할 것으로 예상된다."\n',
#  '4. 피카부 사이드 슬릿\n',
#  '"2018년에는 스커트부터 싸이 하이 드레스까지, 옆이 튿어진 사이드 슬릿 스커트가 유행할 것이다."\n',
#  '5. 100% 면 청바지\n',
#  '청바지만큼 유행을 타지 않는 아이템은 없다. 그중에서도 2018년에 유행할 아이템은 100% 면으로 만들어진 청바지다.\n',
#  '6. 와이드 팬츠\n',
#  '와이드 팬츠는 절대 유행에서 사라지지 않을 패션 아이템이다. 패셔너블하면서 편하기까지 한 와이드 팬츠를 우리는 2018년에도 길거리에서 보게 될 것이다.\n',
#  '7. 시스루 양말\n',
#  '"시스루 양말은 어쩌면 가장 실용적이지 못한 패션 아이템일지 모르지만, 신지 않기에는 너무 귀엽고 사랑스럽다. 시스루 양말과 발레 플랫을 매치하면 누구보다 사랑스러운 룩을 완성할 수 있을 것이다."\n',
#  '2018년에도 우리는 플로럴 패턴을 자주 보게 될 것이다. 플로럴과 다른 패턴을 섞은 프린트 역시 유행할 것으로 전망된다. 만약 여러 패턴을 섞는 게 두렵다고? 비슷한 톤의 옷을 함께 입어 보시라.\n',
#  "입으면 곰돌이로 변신할 수 있는 '테디 코트'는 인조 모피로 만들어진 코트다. 따뜻한 건 덤이다!\n",
#  "우리가 흔히 '골덴'이라고 부르는 코듀로이가 다시 유행할 것이다. 직장에서는 물론이고 퇴근 후에도 편하게 입을 수 있는 아이템이다.\n",
#  '지난 10여년 간의 패션계를 관통했던 키워드는 ‘반짝반짝(bling bling)’이었다. 멋진 패션을 추구하면서도 과하지 않고 세련된 분위기를 연출하는 게 핵심이었다. 그러나 올해는 정반대다. 오랫동안 이어져 온 ‘정통성’을 유지하면서 ‘기본’을 고수하는 게 주된 흐름이 될 것으로 전망된다. 해외 주요 언론들을 통해 2018년 패션계의 트렌드를 알아 봤다.\n',
#  '데님 재킷\n',
#  '"영국 일간 가디언은 2018년을 대표할 패션 아이템으로 ‘데님 재킷’을 지목하면서, “올해는 어디에서나 데님 재킷을 보게 될 것”이라고 내다봤다."\n',
#  '"실제로도 지난해 9월 열린 ‘뉴욕 패션 위크’에서 가장 눈길을 끈 것은 캘빈클라인, 티비, 아담 셀만 등 패션 브랜드가 선보인 클래식한 데님 재킷이었다. 일반적인 재킷보다 조금 더 큰 사이즈에 어깨선이 아래로 내려오는 디자인으로, 캣워크 위 모델들은 어깨에 걸치는 듯한 모습으로 착용했다."\n',
#  '"사실 데님 재킷이 아주 새로운 패션 아이템인 건 아니다. 유명 연예인들이 데님 재킷을 착용한 사진들은 온라인으로 공유돼 널리 퍼지면서, 몇 년 전부터 꾸준히 인기를 이어 왔다. 2016년 가수 리한나는 갈비뼈까지 오는 짧은 길이의 발렌시아가 데님 재킷을, 가수 카니예 웨스트는 하얗게 탈색된 데님 소재에다 진주, 작은 보석 등으로 장식한 발망 재킷을 각각 입어 눈길을 사로잡은 바 있다. 작년에도 데님 재킷은 모델 지지 하디드의 파파라치 컷이 공개되면서 또 한 번 관심을 받았다. 프랑스 의류브랜드 베트멍과 청바지로 유명한 리바이스가 협업해 만든 것이었다."\n',
#  '보라색\n',
#  '"가디언은 또, 올해의 트렌드 색상으로 ‘보라색’을 꼽았다."\n',
#  '"보라색은 미국의 색채 연구소 팬톤이 ‘울트라 바이올렛(Ultra Violet)’이라는 이름으로 내놓은 올해의 컬러다. 구찌, 발렌시아가 등 유명 명품 브랜드들도 이미 ‘2018 봄(spring) 컬렉션’에서 보라색을 전면에 내세웠다. 구찌는 광택 있는 보라색 바탕에 연두색 뱀 그림이 그려진 수트를, 발렌시아가는 얇고 가벼운 소재의 보라색 바지를 캣워크에 올렸다. 의류 브랜드인 에이치 앤 앰(H&M)과 자라(Zara), 화장품 브랜드인 나스(Nars) 등도 보라색을 사용한 티셔츠와 점퍼, 부츠, 매니큐어 등 패션 아이템들을 대거 내놓고 있다."\n',
#  '블랙 터틀넥\n',
#  '이외에도 눈 여겨 볼 만한 트렌드로는 ‘블랙 터틀넥’이 있다.\n',
#  '"미국 일간지 월스트리트저널은 “이제는 더 이상 스티브 잡스만의 것이 아니다”라면서 블랙 터틀넥이 새로운 패션 아이템으로 떠올랐다고 소개했다. 21세기 혁신의 아이콘인 스티브 잡스(1955~2011)가 애용했던 패션이 이제는 상당수가 즐겨 입는 패션 트렌드로 완전히 자리잡은 것이다. 뉴욕 시장 조사 분석가 다니엘 카만코는 “요즘 수많은 디자이너들이 터틀넥을 입고 있다”면서 무늬도, 장식도 없는 터틀넥의 인기를 전했다. 질 샌더, 벨루티 등 디자이너가 생산하는 상품들도 오로지 라벨만 실크 또는 캐시미어로 다르게 표현될 뿐, 기본적인 디자인을 유지하고 있다. 옷에 너무 큰 신경을 쓰지 않기 위해 시작된 ‘반(反)유행’ 패션이 아이러니하게도 새로운 유행이 돼 버린 셈이다. 터틀넥뿐 아니라, 잡스가 무심하게 신은 듯한 뉴발란스 회색 운동화도 발렌시아가, 구찌 등 명품 브랜드 의상의 토대가 됐으니 말이다."\n',
#  '"판타지가 없는 패션을 상상이나 할 수 있을까? 이번 시즌 역시 숱한 브랜드들이 패션 판타지를 구현하기 위해 무대 장치에 막대한 돈을 들였다. 그랑팔레를 늘 새로운 베뉴로 둔갑시키는 샤넬은 컬렉션의 메인 소재인 PVC를 부각시키기 위해 거대한 암석 위를 흐르는 폭포를 만들었고, 돌체&가바나는 이상한 나라의 앨리스의 한 장면처럼 거대한 포커 카드가 둥둥 떠다니는 모습을 연출했다. 그뿐이 아니다. 핑크색 모래 산을 만들어 오토바이 라이더들의 동산을 재현한 펜티X푸마, 여성 만화가 8명과 협업한 만화 벽화를 만든 프라다와 온통 은빛 가루로 뒤덮인 뉴욕의 루프톱을 만들어놓은 코치까지, 그 면모는 풍성하고 다채롭다. 디자이너의 상상력이 동원된 패션쇼의 무대 장치를 보는 일은 어른들만의 놀이동산에 온 듯 즐겁다."\n',
#  '"2018 S/S처럼 안이 훤히 비치는 PVC 소재 가방이 자주 등장한 시즌이 있었을까? 샤넬, 안야 힌드마치, 메종 마르지엘라, 발렌티노 등 PVC 소재를 활용한 브랜드도 많지만 키치한 스타일부터, 점잖은 가방까지 그 표현의 폭도 무척 넓다. 천차만별의 취향을 만족시킬 수 있을 만큼 다양한 비닐 가방이 등장했으니 선택은 당신 몫이다."\n',
#  '"아이스크림처럼 파스텔 컬러가 런웨이를 달콤하게 물들였다. 머리부터 발끝까지 온통 파스텔 컬러로 스타일링한 빅토리아 베컴부터, 아름다운 파스텔 컬러 블록을 보여준 셀린, 자유분방한 70년대를 사랑스러운 컬러로 풀어낸 아크네 스튜디오 등등 온화하고 따뜻하고 긍정적인 컬러로 봄소식을 알린 브랜드들이 이렇게나 많다."\n',
#  '"이번 시즌 런웨이에 올려진 데님은 특정 트렌드를 꼽을 수 없을 만큼 다채롭다. 70년대에 유행한 패치워크 데님에 굽이 낮고 여성스러운 메리제인 슈즈를 매치한 디올, 90년대 섹시 디바의 파워 숄더를 데님에 적용한 톰 포드와 물 빠진 컬러 데님을 헐렁하게 걸쳐 입은 스텔라 매카트니의 데님 등 데님의 디자인적 해석이 돋보인다. 한편 미래적인 방식으로 데님을 해석한 디자이너도 많다. 대표적으로 데님 재킷을 이리저리 절개해 트랜스폼할 수 있게 만든 알렉산더 매퀸의 데님 재킷, 진주 목걸이와 웨스턴 부츠를 매치해 새로운 데님 스타일링을 제안한 오프화이트의 데님이 그렇다."\n',
#  '"여름은 선글라스의 계절이다. 이번 시즌은 렌즈가 눈을 간신히 가릴 만큼 작은 선글라스나, 독특한 형태의 선글라스가 유행할 전망이다. 올여름 옷은 평범하게 입을지라도, 선글라스만큼은 과감한 디자인을 선택해보는 것도 좋을 듯."\n',
#  '"슬립 드레스가 침실에서만 입는 옷이 아님은 너도 알고 나도 알지만, 이번 시즌 슬립 드레스의 활약은 눈이 부실 지경이다. 여자들만의 파자마 파티를 연상케 한 알렉산더 왕은 슬립 드레스를 꼬고, 겹쳐서 더욱 관능적인 룩으로 제안했고, 오스카 드 라 렌타는 스팽글로 촘촘히 수놓은 환상적인 슬립 드레스를 선보여 눈길을 끌었다. 그런가 하면 화려한 크리스털 장식으로 중세풍 슬립 드레스를 만든 코치와 크리스토퍼 케인도 있다."\n',
#  '"힙색 열풍은 이번 시즌에도 계속된다. 다만 힙색을 메는 방식이 조금 달라졌다. 발렌시아가는 힙색을 어깨에 크로스백처럼 착용했고, 프라다는 뒤로 둘러메는 스타일을 제안했다. 힙색을 허리에만 메는 건 고루한 스타일로 취급받는 시대다."\n',
#  '"이번 시즌 깃털을 대하는 디자이너들의 자세가 사뭇 흥미롭다. 메종 마르지엘라의 갈리아노는 트렌치코트부터 드레스, 재킷까지 깃털 장식의 생활화를 외치는 듯한 컬렉션을 펼쳤고, 생로랑은 구름을 타고 다닐 듯한 꿈 같은 드레스를 깃털 소재로 완성했다. 한편 깃털 장식의 새로운 스타일링을 보여준 마르케스 알메이다의 행보는 눈여겨볼 만한데, 깃털이 여성스러운 드레스 소재가 아닌, 거친 스트리트 감성과도 완벽하게 어우러질 수 있는 소재임을 스타일링을 통해 입증했다."\n',
#  '"꽃은 패션 판타지와 떼려야 뗄 수 없는 관계다. 이번 시즌 역시 꽃의 마법은 무대 장치, 드레스, 헤어 장식 등 다양한 분야에서 존재감을 발했다. 알렉산더 매퀸은 근사한 꽃 장식 구조물로 아티스틱한 면모를 뽐냈고, 비밀의 정원을 만든 로다테는 모델들을 하얀 안개꽃으로만 장식해 판타지를 불어넣었다. 한편 모스키노는 모델을 꽃으로 뒤덮어버리거나, 꽃다발 드레스를 만드는 등 자신만의 크레이지한 행보를 이어갔다. 꽃은 무엇을 하든, 몇 번이 반복되든 전혀 지루하지 않다."\n',
#  '"중세풍 옷과 현대적인 프린트의 만남! 가장 현대적인 드라마 <기묘한 이야기>에서 가져온 프린트와 중세풍 블라우스를 매치한 루이 비통, 어깨가 풍성한 블라우스와 줄무늬 팬츠, 프린트 티셔츠를 매치해 절묘한 조합을 보여준 마르케스 알메이다, 고풍스러운 자카드 소재의 톱과 만화 티셔츠를 매치한 프라다까지! 중세와 현대의 만남은 꼭 한 번 도전해볼 스타일링 포인트다."\n',
#  '"스포티한 플랫 샌들의 다양성이 올봄 거리를 화려하게 장식할 예정이다. 그 발랄한 상상력이라니! 어디서도 보지 못한 스타일의 샌들이 활개를 쳤는데, 알록달록한 구슬을 굽에 장착한 마리 카트란주, 구슬 꽃 장식 버클 샌들을 만든 마크 제이콥스, 크록스에 크리스털을 붙인 크리스토퍼 케인, 로봇의 샌들 같은 투박한 고무 샌들을 만든 릭 오웬스, 서로 다른 스터드의 조합을 보여준 프라다 등이 대표적이다. 이번 시즌 샌들에는 뭔가 많이 장식되어 있고, 조금 과장되어 보인다."\n',
#  '"몸의 움직임을 드라마틱하게 연출하는 프린지 소재는 이번 시즌 다양한 무드로 표현되었다. 글래머러스한 드레스를 무대에 올린 발맹, 에스닉 무드로 근사하게 해석한 셀린, 스포티즘과의 새로운 접근을 보여준 몬세와 티셔츠를 잘라 프린지를 만든 아이디어가 돋보인 로에베 등이 있다. 한편 근사한 현대 미슬 작품 같았던 캘빈클라인의 프린지 드레스도 강렬한 인상을 전했다. 시상식 드레스부터 일상에서 향유할 수 있는 티셔츠 스타일로도 소개된 프린지의 신선한 멋을 즐길 때다."\n',
#  '"옷이라 부르기 뭐하고, 아트피스라고 부르기도 뭐한 이번 시즌의 룩들을 소개한다. 먼저 우주에 둥둥 떠다니는 행성과 반인반수를 창조해 새롭고 아름다운 꿈을 꾸게 한 톰 브라운, 불편함을 최대한 로맨틱하게 표현하고 싶었다며 몸에 상자들을 씌워 형태를 만든 뒤 구멍이 숭숭 뚫린 옷으로 그것들을 포장하듯 감싸 하나의 조각을 창조한 릭 오웬스가 있다. 비비안 웨스트우드는 커다란 이불을 두른 모델들을 내보냈고, 레이 가와쿠보는 오타쿠적인 수집광에서 영감 받은 구조적인 드레스를 선보였다. 그뿐일까? 모스키노는 실제 꽃과 나비를 연상케 하는 드레스를 만들어 황홀한 패션의 시간을 선물했다. 아직까지 판타지의 끈을 놓지 않는 그들 덕에 우리는 여전히 꿈을 꾸고 있는지 모른다."\n',
#  '\n',
#  '2018년 가을 컬렉션의 포인트 컬러로 가장 많이 쓰인 색은 비비드한 핑크 컬러가 아닐까. 다수의 디자이너들이 선명한 핑크를 활용한 의상으로 런웨이를 화사하게 밝혔다.\n',
#  '\n',
#  "미국 색채연구소 팬톤 역시 2018 FW 런던 컬렉션을 통해 분석한 트렌드 컬러로 '핑크 피콕'(Pink Peacock) 색상을 꼽았다. 강렬한 마젠타 핑크 색상이다.\n",
#  '\n',
#  "올 가을에는 비비드한 핑크 색상의 슈트를 장만해보면 어떨가. 핑크색 슈트는 걸크러시를 부르는 매니시룩을 연출한다. '알렉산더 왕'처럼 블랙 시스루와 매치해 섹시한 분위기를 내거나 '발렌티노'처럼 진한 레드 컬러 아이템을 활용해 톤온톤 스타일링을 완성할 수 있다.\n",
#  '\n',
#  "강렬한 핑크가 부담스럽다면 핑크 피콕과 함께 선정된 연한 장미빛 핑크인 '멜로우 로즈'(Mellow Rose) 색상을 골라보자. 흰색이 섞인 뮤트톤 핑크인 멜로우 로즈는 오버사이즈 슈트나 블라우스 아이템으로 선택하면 멋스럽다.\n",
#  '"올해 가을과 겨울에는 기존의 어두운 톤에서 벗어나 봄여름보다 화사한 스타일링이 인기를 끌 예정이다. 비비드한 마젠타 핑크는 물론 형광빛 옐로, 오렌지, 퍼플 등의 네온 컬러가 런웨이를 수놓았다."\n',
#  '\n',
#  '특히 네온 컬러는 상하의를 같은 색상으로 맞춰 드라마틱하게 연출하면 더욱 멋스럽다. 일상에서는 포인트 컬러로 센스있게 활용할 것.\n',
#  '"애니멀 패턴이 더욱 과감해졌다. 지브라, 레오파드, 파이톤 등 동물의 무늬가 니트 풀오버나 블라우스에는 물론 보디슈트와 원피스 등의 전체에 담겼다."\n',
#  '\n',
#  "애니멀 프린트는 야성적인 느낌을 풍겨 아이템 하나만으로 섹시한 분위기를 자아낸다. 이번 시즌에는 패턴이 많이 그려진 것일수록 트렌디한 아이템이 될 예정이다. '로베르토 카발리'가 선보인 보디슈트나 원피스를 참고하자.\n",
#  '\n',
#  "애니멀 프린트는 아니지만 최근 활동을 마친 그룹 블랙핑크의 제니가 '뚜두뚜두' 뮤직비디오에서 입은 달 패턴 의상이 화제가 된 바 있다. 제니는 타이트한 톱과 레깅스를 같은 패턴과 색으로 고르고 보디슈트처럼 착용해 남다른 패션 소화력을 뽐냈다.\n",
#  '"애니멀 프린트가 부담스럽다면 체크, 스트라이프, 기하학적 패턴 등에 주목하자. 특히 하나의 패턴 보다 여러가지 색과 패턴을 활용한 아이템이 인기다. 마치 옷 여러개를 잘라 붙인듯 컬러 블로킹한 아이템이 메가 트렌드 아이템으로 급부상 중이다."\n',
#  '\n',
#  "체크무늬 원피스 위에 다른 색 다른 체크 무늬의 재킷을 레이어드하면 쉽다. '사카이' '버버리' 베르사체' 등 글로벌 디자이너 브랜드들이 앞다투어 선보인 패턴 블로킹 의상을 참고하자.\n",
#  '\n',
#  "지난 패션위크에서 다수의 스타들이 선보인 '반반 패션'을 떠올려보자. 다양한 패턴이 복잡하게 섞인 의상이 다소 화려하고 과하게 느껴진다면 좌우 반반으로 나뉘거나 커다란 스트라이프처럼 컬러 블로킹된 것을 고르자. '마르니'의 가을 컬렉션을 참고할 것.\n",
#  '2018년 한해는 레트로가 패션을 지배했다.\n',
#  '\n',
#  '"레트로(Retro)는 복고풍을 뜻하는 단어로?회상, 회고, 추억이라는 뜻의 영어 ‘Retrospect’에서 나온 말이다. 최근 과거를 회상하는 영화와 드라마 등 문화콘텐츠가 함께 범람하면서 패션의 영역에도 자연스럽게 복고풍 레트로가 자리잡았다. 단순히 패션의 감각적인 스타일을 전하기 보단 과거의 시대적 상황을 재현하고 현대의 감성에 맞게 새로운 가치의 창조도 이뤄진다.?"\n',
#  '\n',
#  '"2018년에는 연초 평창동계올림픽의 개최로 롱패딩 열풍이 일었다. 이를 레트로 패션에 적용해 일명 \'돕바\'라고 불리는 운동선수 스타일, 혹은 아저씨 스타일의 롱패딩이 유행했다. 돕바는 일본어 토파(トッパ?)에서 나온 말로?허리 밑으로 엉덩이 가려주는 옷을 주로 일컽는다. 일부 지역에서는 방언처럼 외투를 돕바라고 부르기도 한다."\n',
#  '\n',
#  '이와 더불어 불경기의 여파로 실용성이 높은 아재(아저씨) 패션도 유행했다. 타인의 눈을 신경쓰는 패션이 아니라 오히려 역발상으로 실용성에 초점을 맞춘 독특한 패션과 장신구가 매력을 발산하는 형태다. 여성들조차 편한 플랫형 운동화를 신거나 조깅화를 자주 신고 다녔다. 또한 전대 모양의 패니백이나 옷차림이 편한 체육복도 인기가 많았다. 복고풍의 트렌드에 맞춰 옷에는 반짝이나 물방울무늬 패션도 선호했다.\n',
#  '\n',
#  '"복고풍이 사회의 유행으로 떠오르면서 역사가 오래된 올드 브랜드들의 인기도 올랐다.?폴로 랄프로렌, 버버리 등 외국의 유명 올드 브랜드들의 직구도 활발한 한해였다. 또 다양한 브랜드들의 콜라보 작업도 활발해 새로운 브랜드 가치창출도 꾸준히 이어졌다."\n',
#  '\n',
#  '워킹 클래스 스트리트웨어\n',
#  '\n',
#  '"디자이너 사무엘 로스(Samuel Ross)가 만든 스트리트웨어 브랜드 어-콜드-워*(A-COLD-WALL*)는 과포화 상태에 도달한 스트리트웨어 시장이 어디로 향하는지 길을 제시한다. 사회적 계급과 갈등, 주변 일상 풍경이 현대 영국의 그림자이자 현실이라는 것을 인지한 어-콜드-워*는 2015년 데뷔 이래 소위 ‘워킹 클래스 히어로(Working Class Hero’ 브랜드로 자리매김했다. 노동자 계급의 정서와 감각을 신중하고 복합적인 디자인으로 담아낸 이 런던 스트리트웨어는 독특한 위치를 선점함과 동시에 모순적이지만 세계 온갖 고급 편집매장의 벽 한쪽을 차지하고 있다."\n',
#  '\n',
#  '"어-콜드-워* 컬렉션은 옷 자체에 담아낸 다양한 기술과 은유가 모여 하나의 작품처럼 보인다. 거의 모든 기성복 컬렉션에 특유의 간결한 로고 아트워크, 사진과 콜라주를 포함한 그래픽과 시각 이미지, 그리고 손으로 염색하거나 직접 마감한 수제작(Handmade) 디테일이 가득하다. 흔히 보이는 스트리트웨어의 화려한 색채 팔레트는 이 브랜드에 없다. 대신 앞서 언급한 시각 언어(Visual Language)를 든든하게 뒷받침하는 ? 하지만 180도 다른 ? 첨단(High-Technology) 소재들이 함께 있다."\n',
#  '\n',
#  '"어-콜드-워* 역시 인스타그램 같은 사회관계망서비스 SNS를 적극적으로 활용하고 겉으로 드러나는 이미지를 중시한다. 하지만 유행을 좇는 청년문화(Youth culture) 이미지에 함몰하지 않고, 옷을 만든 이유와 디자인 모티브를 차분하게 설명한다. 스니커즈 문화와 로고에 열광하는 동시대 청년뿐만 아니라 리치 더 키드(Rich the Kid) 같은 미국 힙합의 떠오르는 스타가 그들의 충실한 고객이자 친구이며, 지지자를 자처한다."\n',
#  '\n',
#  '하이테크 스트리트웨어\n',
#  '\n',
#  '"나이키(Nike)와 협업한 에어 프레스토(Air Presto)와 에어포스원(Air Force 1) 시리즈로 널리 알려진 아크로님(ACRONYM®)은 베를린에 기반을 둔 하이테크 스트리트웨어의 선두주자이다. 크리에이티브 디렉터 에롤슨 휴의 작업 또한, 2018년 스트리트웨어의 움직임을 읽을 수 있는 단초를 제공한다."\n',
#  '\n',
#  '"기능성 의류 라인으로 출발했지만 명맥이 끊긴 ACG 컬렉션은 지난 2년간, 에롤슨 휴(Errolson Hugh)의 지휘 아래 ‘나이키랩 올 컨디션스 기어(NikeLab All Conditions Gear)’로 새롭게 출발했다. 아크로님과 ACG는 일반적인 의류에 사용하지 않는 지퍼와 스트랩 같은 다양한 부자재를 세심한 재단과 신중한 마무리 과정을 거친다. 실제로 움직임이 많이 필요한 상황이나 사람들에게 최적화한 세련되고 비밀스러운 기성복으로 완성되었다."\n',
#  '\n',
#  '"아크로님을 ‘고스(Goth’와 다크웨어(Darkwear) 장르와 접점이 있는 고가의 스트리트웨어로 묶는 경향도 있지만, 이는 편협한 해석이다. 에롤슨 휴는 사람들이 입는 옷이 겉보기에 아름다운 특징을 지니는 것 이상으로 실용적인 면과 옷 자체가 지닌 기능적 면모에 충실하게 다가서며, 순간 휘발하고 사라지는 이미지 중심의 시대를 역설적으로 돌파한다. 이제 갓 패션에 흥미를 느끼는 이들보다 전문가들에게 더 높은 평가를 받는 이유이기도 하다."\n',
#  '\n',
#  '하이브리드 유스 컬처?\n',
#  '\n',
#  '"어-콜드-워*와 아크로님이 자국 도시 정서에 핸드메이드 기법과 전통 의류 제작, 그리고 첨단 소재를 혼합한 하이브리드 스트리트웨어를 지향한다면, 2018년 스트리트웨어의 마지막 퍼즐 조각은 디자이너 매튜 윌리엄스(Matthew Williams)에게 있다."\n',
#  '\n',
#  '"하이스노비어티(Highsnobiety) 인터뷰 기사에서 언급했듯이 그는 ‘패션을 사랑하는 사람들’을 위한 옷을 만든다. 매튜 윌리엄스가 본격적으로 알려진 계기는 거대 명품 기업 LVMH가 주관하는 시상식 최종 6인에 든 2016년이었다. 하지만 자신의 브랜드 알릭스 스튜디오(ALYX Studio)를 만들기 전, 이미 버질 아블로 그리고 카니예 웨스트와 함께 프로젝트 브랜드를 만들고 밀레니얼 세대에게 패션을 전파한 상징적 인물이라는 점은 많이 알려지지 않았다.?"\n',
#  '\n',
#  '"알릭스 스튜디오는 남성과 여성을 위한 유니섹스 컬렉션을 만든다. 일반 기성복에 쓰이지 않던 금속 벨트 잠금장치를 이탈리아 공방에서 정성스럽게 세공하고, 라프 시몬스(Raf Simons)의 음울한 도시 청소년 정서와 헬무트 랑(Helmut Lang)이 이룩한 최소주의, 펑크(Punk)와 레이브(Rave)처럼 뒷골목 클럽과 나이트 라이프의 퇴폐적인 아름다움이 컬렉션 안에 녹여낸다. 최근 컬렉션 이미지를 보면, 종종 이 스킨헤드 디자이너가 미국 캘리포니아에서 나고 자랐다는 배경을 잊게 될 정도다.?"\n',
#  '\n',
#  '"그는 사진가 닉 나이트(Nick Night)나 노부요시 아라키(Nobuyoshi Araki), 팝 수퍼스타 레이디 가가(Lady Gaga)와 함께 일했다. 시대를 이끄는 음악을 만들고, 기성세대와 다른 이야기를 담아낸 패션 잡지를 펴내는 친구들 또한 세계 곳곳에 포진해 있다. 또한, 알릭스 스튜디오는 패션을 사회와 분리하여 그저 돈을 버는 수단으로 사용하지 않고 오히려 사회에 적극적으로 개입한다. 매튜 윌리엄스는 공공연하게 인종 차별 문제를 심각하게 받아들이고 반대한다고 밝혔으며, 그러한 요소를 녹인 티셔츠를 기습 출시하기도 한다.?"\n',
#  '\n',
#  '"알릭스 스튜디오를 한마디로 응축하면 ‘혼돈(chaos)의 재정립’이다. 직간접적으로 경험한 온갖 이미지와 심상, 거리 예술과 오래된 도시 문화, 컬렉션을 만들며 오가는 이탈리아 도시들과 미국 동·서부의 분위기가 뒤섞여 있다. 그의 컬렉션은 스트리트웨어가 걸어온 ‘모방으로부터 나오는 창조’의 연장선에 있지만, 실제로 모방하여 선보이기에는 이미 정체성이 된 요소가 뚜렷하다. 그래서일까? 오프화이트의 버질 아블로의 뒤를 잇는 하이엔드 스트리트웨어의 대표주자가 될 가능성이 높다고 호사가들은 얘기한다."\n',
#  '\n',
#  '새로운 트렌드는 없다(There’s no more the new trend)\n',
#  '\n',
#  '"사실 요즘 세상에 새로운 트렌드는 없다. 사람들은 여전히 과거에서 영감을 얻고, 모두가 이야기하는 1990년대는 실제로 그 시절을 겪지 않은 밀레니얼 세대가 가장 좋아하는 스타일로 둥지를 틀었다. 우리는 과거에서 새로운 미래를 보거나 재해석한다. 하지만 위에 언급한 세 개의 브랜드처럼 그들의 지역 문화와 첨단 기술, 그렇게 오래되지 않은 대가들의 작업과 항상 풋풋하고 불안하게 존재하던 청년 문화의 단편을 모아 쏟아내는 스트리트웨어도 곁에 있다. 2018년의 스트리트웨어가 향하는 조금 다른 방향은 주류를 향한 반동이자, 의미 있는 발자국이 될 것이다."\n']

# %%
twitter = Twitter() 
morphs = [] 
for sentence in lists:
    morphs.append(twitter.pos(sentence)) 
print(morphs)
# Out:
# C:\Users\KYN\anaconda3\envs\pydatavenv\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [[('1', 'Number'), ('.?', 'Punctuation'), ('세로', 'Noun'), ('무늬', 'Noun'), ('?(', 'Punctuation'), ('Vertical', 'Alpha'), ('Stripes', 'Alpha'), (')', 'Punctuation'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('"', 'Punctuation'), ('봄', 'Noun'), (',', 'Punctuation'), ('여름', 'Noun'), ('이', 'Josa'), ('되면', 'Verb'), ('스트라이프', 'Noun'), ('패턴', 'Noun'), ('의', 'Josa'), ('옷', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('많이', 'Adverb'), ('입', 'Noun'), ('을', 'Josa'), ('텐데요', 'Eomi'), ('."', 'Punctuation'), ('\n', 'Foreign')], [('심플', 'Noun'), ('하면서도', 'Verb'), ('화려한듯', 'Adjective'), ('한', 'Determiner'), ('느낌', 'Noun'), ('의', 'Josa'), ('스트라이프', 'Noun'), ('!', 'Punctuation'), ('\n', 'Foreign')], [('2018년', 'Number'), ('올해', 'Noun'), ('는', 'Josa'), ('세로', 'Noun'), ('스트라이프', 'Noun'), ('가', 'Josa'), ('강세', 'Noun'), ('라고', 'Josa'), ('하네요', 'Verb'), (':)', 'Punctuation'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('2', 'Number'), ('.', 'Punctuation'), ('옐로우', 'Noun'), ('컬러', 'Noun'), ('(', 'Punctuation'), ('Yellow', 'Alpha'), (')', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('올해', 'Noun'), ('의', 'Josa'), ('색', 'Noun'), ('은', 'Josa'), ("'", 'Punctuation'), ('울트라', 'Noun'), ('바이올렛', 'Noun'), ("'", 'Punctuation'), ('으로', 'Josa'), ('선정', 'Noun'), ('됐지만', 'Verb'), (',?"', 'Punctuation'), ('\n', 'Foreign')], [('패션위크', 'Noun'), ('런웨이', 'Noun'), ('에서는', 'Josa'), ('옐로우', 'Noun'), ('컬러', 'Noun'), ('가', 'Josa'), ('눈', 'Noun'), ('에', 'Josa'), ('많이', 'Adverb'), ('띄었는데요', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')], [('봄', 'Noun'), ('을', 'Josa'), ('알리는', 'Verb'), ('옐로우', 'Noun'), ('는', 'Josa'), ('?', 'Punctuation'), ('화사함을', 'Adjective'), ('돋보이기', 'Verb'), ('위해', 'Noun'), ('?', 'Punctuation'), ('\n', 'Foreign')], [('매년', 'Noun'), ('주목', 'Noun'), ('받는', 'Verb'), ('컬러', 'Noun'), ('가', 'Josa'), ('아닌가', 'Adjective'), ('싶어요', 'Verb'), ('!', 'Punctuation'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('3', 'Number'), ('.', 'Punctuation'), ('트레인', 'Noun'), ('(', 'Punctuation'), ('Train', 'Alpha'), (')', 'Punctuation'), ('\n', 'Foreign')], [('트레인', 'Noun'), ('은', 'Josa'), ("'", 'Punctuation'), ('옷자락', 'Noun'), ('을', 'Josa'), ('끌다', 'Verb'), ("'", 'Punctuation'), ('라는', 'Josa'), ('뜻', 'Noun'), ('을', 'Josa'), ('가지', 'Noun'), ('고', 'Josa'), ('있는데요', 'Adjective'), ('.', 'Punctuation'), ('\n', 'Foreign')], [('드레스', 'Noun'), ('나', 'Josa'), ('옷', 'Noun'), ('의', 'Josa'), ('뒷자락', 'Noun'), ('을', 'Josa'), ('길게', 'Adjective'), ('늘어', 'Verb'), ('뜨려', 'Verb'), ('바닥', 'Noun'), ('에', 'Josa'), ('끌리는', 'Verb'), ('옷', 'Noun'), ('을', 'Josa'), ('말', 'Noun'), ('합니다', 'Verb'), ('!', 'Punctuation'), ('\n', 'Foreign')], [('길이', 'Noun'), ('만', 'Josa'), ('길어졌을', 'Verb'), ('뿐인데요', 'Adjective'), ('여성', 'Noun'), ('스러운', 'Josa'), ('느낌', 'Noun'), ('이', 'Josa'), ('물씬', 'Noun'), ('나', 'Noun'), ('는', 'Josa'), ('것', 'Noun'), ('같아요', 'Adjective'), (':->', 'Punctuation'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('4', 'Number'), ('.', 'Punctuation'), ('프린지', 'Noun'), ('(', 'Punctuation'), ('Fringe', 'Alpha'), (')', 'Punctuation'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('70년', 'Number'), ('대', 'Foreign'), ('레트로', 'Noun'), ('와', 'Josa'), ('히피', 'Noun'), ('스타일', 'Noun'), ('이', 'Josa'), ('유행', 'Noun'), ('하는', 'Verb'), ('요즘', 'Noun'), (',?"', 'Punctuation'), ('\n', 'Foreign')], [('보헤미안', 'Noun'), ('분위기', 'Noun'), ('의', 'Josa'), ('프린지', 'Noun'), ('장식', 'Noun'), ('으로', 'Josa'), ('?', 'Punctuation'), ('개성', 'Noun'), ('넘치는', 'Adjective'), ('패션', 'Noun'), ('을', 'Josa'), ('완성', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있겠죠', 'Adjective'), ('?', 'Punctuation'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('5', 'Number'), ('.', 'Punctuation'), ('올', 'Verb'), ('화이트', 'Noun'), ('(', 'Punctuation'), ('All', 'Alpha'), ('White', 'Alpha'), (')', 'Punctuation'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('"', 'Punctuation'), ('무난', 'Noun'), ('해', 'Verb'), ('보이는', 'Verb'), ('화이트', 'Noun'), ('는', 'Josa'), ('언제나', 'Adverb'), ('사랑받는', 'Verb'), ('컬러', 'Noun'), ('이지만', 'Josa'), (',?"', 'Punctuation'), ('\n', ' ...

# %%
noun_adj_adv_list=[] 
for sentence in morphs : 
    for word, tag in sentence : 
        if tag in ['Noun'] and ("것" not in word) and ("내" not in word)and ("나" not in word)and ("수"not in word) and("게"not in word)and("말"not in word): 
            noun_adj_adv_list.append(word) 

print(noun_adj_adv_list)
# Out:
# ['세로', '무늬', '봄', '여름', '스트라이프', '패턴', '옷', '입', '심플', '느낌', '스트라이프', '올해', '세로', '스트라이프', '강세', '옐로우', '컬러', '올해', '색', '울트라', '바이올렛', '선정', '패션위크', '런웨이', '옐로우', '컬러', '눈', '봄', '옐로우', '위해', '매년', '주목', '컬러', '트레인', '트레인', '옷자락', '뜻', '가지', '드레스', '옷', '뒷자락', '바닥', '옷', '길이', '여성', '느낌', '물씬', '프린지', '레트로', '히피', '스타일', '유행', '요즘', '보헤미안', '분위기', '프린지', '장식', '개성', '패션', '완성', '화이트', '무난', '화이트', '컬러', '올해', '상', '하의', '모두', '화이트', '매치', '화이트', '룩', '트렌드', '여름', '트렌디', '패션', '패', '팩', '패', '팩', '엉덩이', '뜻', '배낭', '뜻', '의', '합성어', '힙색', '유행', '아이템', '유행', '백', '지금', '스트릿', '지금', '시즌', '트렌드', '유행', '스타일', '시작', '트렌드', '패션', '트렌드', '살짝', '변형', '스트릿', '패션', '쇼미더머니', '트렌드', '힙합', '스타일', '스트릿', '패션', '자극', '지금', '시즌', '스트릿', '패션', '블', '레이저', '슬랙스', '로퍼', '등', '아이템', '활용', '스트릿', '스타일', '스트릿', '패션', '열풍', '잠깐', '유행', '아메', '카', '스타일', '종종', '볼', '시즌', '패션', '트렌드', '이전', '트렌드', '스타일', '볼', '시즌', '앞', '테크', '웨어', '현재', '패션', '트렌드', '발전', '가능성', '스타일', '테크', '웨어', '시즌', '잠깐', '각', '스타일', '지금', '테크', '웨어', '착용', '시즌', '언급', '시즌', '트렌드', '발전', '가능성', '스타일', '테크', '웨어', '고어텍스', '코듀라같', '첨단', '소재', '캐', '쥬얼', '스타일', '만난', '패션', '양쪽', '사람', '선호', '스타일', '저리', '현재', '한국', '연예인', '테크', '웨어', '방송', '출연', '모습', '종종', '볼', '트렌드', '트렌드', '만큼', '개성', '적', '스타일', '스트릿', '패션', '래퍼', '착용', '걸', '주목', '트렌드', '아이템', '힙색', '시즌', '트렌드', '아이템', '크로스', '바디', '백', '힙색', '과거', '힙색하', '오직', '위', '가방', '배달', '부들', '돈', '보관', '가방', '패션', '전혀', '디자인', '제품', '지금', '스트릿', '패션', '스타', '일링', '종종', '사용', '아이템', '브랜드', '패션', '쪽', '겨냥', '디자인', '힙색', '발매', '뿐', '힙색', '앞', '트렌드', '테크', '웨어', '코디', '아이템', '힙색', '처음', '아이템', '새', '개성', '디자인', '모두', '만족', '트렌드', '아이템', '올해', '컬러', '퍼플', '패션계', '선정', '올해', '색상', '보라', '보라', '호불호', '색상', '개성', '색상', '무조건', '생', '보라색', '의류', '건', '보라색', '보라색', '의류', '매력', '트렌디', '꼭', '의류', '보라색', '악세사리', '포인트', '무작정', '트렌드', '트렌드', '무시', '볼', '자신', '스타일', '트렌드', '베스트', '패션', '컬렉션', '아이템', '베레모', '유행', '전망', '옷', '매치', '울트라', '바이올렛', '울트라', '바이올렛', '팬톤', '선정', '올해', '컬러', '재작년', '세레', '티', '로', '쿼츠', '작년', '너리', '울트라', '바이올렛', '역시', '패션계', '예상', '스테이', '트먼트', '주얼리', '유행', '그', '유행', '사이즈', '링', '귀걸이', '모양', '귀걸이', '크기', '뭐', '유행', '예상', '피카', '부', '사이드', '슬릿', '스커트', '싸이', '하이', '드레스', '옆', '튿', '어진', '사이드', '슬릿', '스커트', '유행', '면', '청바지', '청바지', '유행', '타지', '아이템', '중', '유행', '아이템', '면', '청바지', '와이드', '팬츠', '와이드', '팬츠', '절대', '유행', '패션', '아이템', '패셔너블', '와이드', '팬츠', '우리', '길거리', '시스루', '시스루', '어쩌면', '가장', '실용', '못', '패션', '아이템', '일지', '신지', '시스루', '발레', '플랫', '매치', '누구', '룩', '완성', '우리', '로럴', '패턴', '자주', '로럴', '다른', '패턴', '프린트', '역시', '유행', '전망', '만약', '여러', '패턴', '톤', '옷', '보시', '곰돌이', '변신', '테디', '코트', '인조', '모피', '코트', '건', '덤', '우리', '골덴', '코듀로이', '다시', '유행', '직장', '퇴근', '후', '입', '아이템', '지난', '년', '간의', '패션계', '관통', '패션', '추구', '과', '분위기', '연출', '핵심', '올해', '정반대', '온', '정통', '유지', '기본', '흐름', '전망', '해외', '주요', '언론', '통해', '패션계', '트렌드', '알', '데님', '재킷', '영국', '일간', '가디언', '대표', '패션', '아이템', '데님', '재킷', '지목', '올해', '어디', '데님', '재킷', '실제', '도', '지난해', '뉴욕', '패션', '위', '가장', '눈길', '끈', '캘빈', '클라인', '티비', '아담', '셀', '등', '패션', '브랜드', '클래식', '데님', '재킷', '일반', '재킷', '조금', '더', '사이즈', '어깨', '선', '아래', '디자인', '캣워크', '위', '모델', '어깨', '듯', '모습', '착용', '사실', '데님', '재킷', '아주', '패션', '아이템', '건', '유명', '연예인', '데님', '재킷', '착용', '사진', '온라인', '공유', '널리', '몇', '년', '전', '인기', '갈비뼈', '길이', '발렌시아', '데님', '재킷', '카니', '예', '웨스트', '탈색', '데님', '소재', '진주', '보석', '등', '장식', '발망', '재킷', '각각', '눈길', '바', '작년', '데님', '재킷', '모델', '지지', '하디드', '파파라치', '컷', '공개', '또', '번', '관심', '프랑스', '의류', '브랜드', '베트멍', '청바지', '리바이스', '협업', '보라색', '가디언', '또', '올해', '트렌드', '색상', '보라색', '꼽았다', '보라색', '미국', '색채', '연구소', '팬톤', '울트라', '바이올렛', '이름', '올해', '컬러', '구찌', '발렌시아', '등', '유명', '명품', '브랜드', '봄', '컬렉션', '보라색', '전면', '구찌', '광택', '보라색', '바탕', '연두색', '뱀', '그림', '발렌시아', '소재', '보라색', '바지', '캣워크', '의류', '브랜드', '에이치', '앤', '앰', '과', '자라', '화장품', '브랜드', '등', '보라색', '사용', '티셔츠', '점퍼', '부츠', '매니큐어', '등', '패션', '아이템', '대거', '블랙', '터틀넥', '이외', '눈', '볼', '만', '트렌드', '블랙', '터틀넥', '이', '미국', '일간', '월 ...

# %%
count = Counter(noun_adj_adv_list)
words = dict(count.most_common())
words
# Out:
# {'패션': 46,
#  '트렌드': 28,
#  '아이템': 25,
#  '유행': 23,
#  '컬러': 22,
#  '웨어': 22,
#  '스타일': 21,
#  '등': 21,
#  '브랜드': 21,
#  '시즌': 20,
#  '데님': 20,
#  '옷': 19,
#  '드레스': 17,
#  '스트리트': 16,
#  '컬렉션': 15,
#  '재킷': 14,
#  '패턴': 13,
#  '그': 13,
#  '장식': 12,
#  '소재': 12,
#  '올해': 11,
#  '스타': 11,
#  '보라색': 11,
#  '이번': 11,
#  '핑크': 11,
#  '힙색': 10,
#  '디자이너': 10,
#  '매치': 9,
#  '디자인': 9,
#  '색상': 9,
#  '의': 8,
#  '스트릿': 8,
#  '위': 8,
#  '일링': 8,
#  '의류': 8,
#  '로': 8,
#  '활용': 7,
#  '다른': 7,
#  '프린트': 7,
#  '듯': 7,
#  '이': 7,
#  '꽃': 7,
#  '무늬': 6,
#  '봄': 6,
#  '눈': 6,
#  '여성': 6,
#  '프린지': 6,
#  '화이트': 6,
#  '볼': 6,
#  '테크': 6,
#  '착용': 6,
#  '역시': 6,
#  '인기': 6,
#  '미국': 6,
#  '티셔츠': 6,
#  '터틀넥': 6,
#  '뒤': 6,
#  '워': 6,
#  '현대': 6,
#  '샌들': 6,
#  '슈트': 6,
#  '문화': 6,
#  '이미지': 6,
#  '스트라이프': 5,
#  '색': 5,
#  '울트라': 5,
#  '바이올렛': 5,
#  '뜻': 5,
#  '레트로': 5,
#  '분위기': 5,
#  '완성': 5,
#  '지금': 5,
#  '사람': 5,
#  '과거': 5,
#  '가방': 5,
#  '우리': 5,
#  '가장': 5,
#  '톤': 5,
#  '연출': 5,
#  '알': 5,
#  '실제': 5,
#  '모델': 5,
#  '전': 5,
#  '발렌시아': 5,
#  '블랙': 5,
#  '의상': 5,
#  '판타지': 5,
#  '스튜디오': 5,
#  '해석': 5,
#  '슬립': 5,
#  '깃털': 5,
#  '고풍': 5,
#  '스': 5,
#  '사회': 5,
#  '콜드': 5,
#  '여름': 4,
#  '선정': 4,
#  '위해': 4,
#  '개성': 4,
#  '종종': 4,
#  '언급': 4,
#  '첨단': 4,
#  '만큼': 4,
#  '사용': 4,
#  '패션계': 4,
#  '건': 4,
#  '포인트': 4,
#  '전망': 4,
#  '티': 4,
#  '청바지': 4,
#  '팬츠': 4,
#  '시스루': 4,
#  '실용': 4,
#  '과': 4,
#  '대표': 4,
#  '조금': 4,
#  '더': 4,
#  '어깨': 4,
#  '바': 4,
#  '표현': 4,
#  '무대': 4,
#  '를': 4,
#  '프라다': 4,
#  '처럼': 4,
#  '한편': 4,
#  '알렉산더': 4,
#  '선글라스': 4,
#  '중세': 4,
#  '시대': 4,
#  '블라우스': 4,
#  '창조': 4,
#  '가을': 4,
#  '애니멀': 4,
#  '복': 4,
#  '또한': 4,
#  '아크': 4,
#  '도시': 4,
#  '알릭스': 4,
#  '느낌': 3,
#  '옐로우': 3,
#  '주목': 3,
#  '요즘': 3,
#  '모두': 3,
#  '룩': 3,
#  '트렌디': 3,
#  '패': 3,
#  '열풍': 3,
#  '카': 3,
#  '앞': 3,
#  '가능성': 3,
#  '모습': 3,
#  '돈': 3,
#  '뿐': 3,
#  '자신': 3,
#  '팬톤': 3,
#  '사이즈': 3,
#  '뭐': 3,
#  '면': 3,
#  '와이드': 3,
#  '플랫': 3,
#  '자주': 3,
#  '지난': 3,
#  '통해': 3,
#  '어디': 3,
#  '뉴욕': 3,
#  '눈길': 3,
#  '일반': 3,
#  '유명': 3,
#  '또': 3,
#  '번': 3,
#  '협업': 3,
#  '색채': 3,
#  '구찌': 3,
#  '명품': 3,
#  '이제': 3,
#  '잡스': 3,
#  '소개': 3,
#  '반': 3,
#  '장치': 3,
#  '톱': 3,
#  '면모': 3,
#  '선택': 3,
#  '파스텔': 3,
#  '런웨': 3,
#  '제안': 3,
#  '형태': 3,
#  '더욱': 3,
#  '꿈': 3,
#  '이야기': 3,
#  '예정': 3,
#  '움직임': 3,
#  '일상': 3,
#  '멋': 3,
#  '비비드': 3,
#  '보디': 3,
#  '원피스': 3,
#  '참고': 3,
#  '최근': 3,
#  '체크': 3,
#  '블로킹': 3,
#  '재': 3,
#  '작업': 3,
#  '향': 3,
#  '이자': 3,
#  '정서': 3,
#  '기성복': 3,
#  '청년': 3,
#  '에롤슨': 3,
#  '매튜': 3,
#  '윌리엄스': 3,
#  '세로': 2,
#  '입': 2,
#  '패션위크': 2,
#  '런웨이': 2,
#  '트레인': 2,
#  '길이': 2,
#  '상': 2,
#  '하의': 2,
#  '팩': 2,
#  '엉덩이': 2,
#  '백': 2,
#  '시작': 2,
#  '힙합': 2,
#  '잠깐': 2,
#  '현재': 2,
#  '발전': 2,
#  '선호': 2,
#  '연예인': 2,
#  '걸': 2,
#  '크로스': 2,
#  '전혀': 2,
#  '새': 2,
#  '만족': 2,
#  '퍼플': 2,
#  '보라': 2,
#  '매력': 2,
#  '꼭': 2,
#  '작년': 2,
#  '예상': 2,
#  '귀걸이': 2,
#  '모양': 2,
#  '사이드': 2,
#  '슬릿': 2,
#  '스커트': 2,
#  '하이': 2,
#  '못': 2,
#  '로럴': 2,
#  '코트': 2,
#  '년': 2,
#  '온': 2,
#  '유지': 2,
#  '기본': 2,
#  '영국': 2,
#  '일간': 2,
#  '가디언': 2,
#  '도': 2,
#  '끈': 2,
#  '캘빈': 2,
#  '클라인': 2,
#  '아래': 2,
#  '캣워크': 2,
#  '사실': 2,
#  '사진': 2,
#  '널리': 2,
#  '몇': 2,
#  '카니': 2,
#  '예': 2,
#  '웨스트': 2,
#  '진주': 2,
#  '꼽았다': 2,
#  '연구소': 2,
#  '부츠': 2,
#  '이상': 2,
#  '스티브': 2,
#  '자리': 2,
#  '시장': 2,
#  '분석': 2,
#  '신경': 2,
#  '운동화': 2,
#  '샤넬': 2,
#  '카드': 2,
#  '둥둥': 2,
#  '핑크색': 2,
#  '재현': 2,
#  '만화': 2,
#  '온통': 2,
#  '코치': 2,
#  '다채롭다': 2,
#  '상상력': 2,
#  '일': 2,
#  '등장': 2,
#  '마치': 2,
#  '메종': 2,
#  '마르지': 2,
#  '엘라': 2,
#  '발렌티노': 2,
#  '셀린': 2,
#  '적용': 2,
#  '톰': 2,
#  '카트': 2,
#  '미래': 2,
#  '방식': 2,
#  '퀸': 2,
#  '오프': 2,
#  '과감': 2,
#  '연상': 2,
#  '케': 2,
#  '왕': 2,
#  '크리스털': 2,
#  '크리스토퍼': 2,
#  '케인': 2,
#  '허리': 2,
#  '마르케스': 2,
#  '메이': 2,
#  '행보': 2,
#  '감성': 2,
#  '관계': 2,
#  '존재': 2,
#  '모스': 2,
#  '키노': 2,
#  '만남': 2,
#  '드라마': 2,
#  '조합': 2,
#  '거리': 2,
#  '구슬': 2,
#  '릭': 2,
#  '몸': 2,
#  '무드': 2,
#  '닉': 2,
#  '작품': 2,
#  '시상식': 2,
#  '기도': 2,
#  '조각': 2,
#  '영감': 2,
#  '런던': 2,
#  '피콕': 2,
#  '마젠타': 2,
#  '빛': 2,
#  '로우': 2,
#  '오버': 2,
#  '네온': 2,
#  '제니': 2,
#  '뚜': 2,
#  '개': 2,
#  '버버리': 2,
#  '한해': 2,
#  '회상': 2,
#  '감각': 2,
#  '상황': 2,
#  '가치': 2,
#  '롱패딩': 2,
#  '아저씨': 2,
#  '지역': 2,
#  '오히려': 2,
#  '올드': 2,
#  '워킹': 2,
#  '클래스': 2,
#  '계급': 2,
#  '동시': 2,
#  '세계': 2,
#  '온갖': 2,
#  '자체': 2,
#  '기술': 2,
#  '로고': 2,
#  '시각': 2,
#  '제작': 2,
#  '적극': 2,
#  '이유': 2,
#  '친구': 2,
#  '하이테크': 2,
#  '주자': 2,
#  '휴': 2,
#  '기능': 2,
#  '출발': 2,
#  '하이브리드': 2,
#  '버질': 2,
#  '밀레': 2,
#  '얼': 2,
#  '세대': 2,
#  '이탈리아': 2,
#  '요소': 2,
#  '모방': 2,
#  '심플': 1,
#  '강세': 1,
#  '매년': 1,
#  '옷자락': 1,
#  '가지': 1,
#  '뒷자락': 1,
#  '바닥': 1,
#  '물씬': 1,
#  '히피': 1,
#  '보헤미안': 1,
#  '무난': 1,
#  '배낭': 1,
#  '합성어': 1,
#  '살짝': 1,
#  '변형': 1,
#  '쇼미더머니': 1,
#  '자극': 1,
#  '블': 1,
#  '레이저': 1,
#  '슬랙스': 1,
#  '로퍼': 1,
#  '아메': 1,
#  '이전': 1,
#  '각': 1,
#  '고어텍스': 1,
#  '코듀라같': 1,
#  '캐': 1,
#  '쥬얼': 1,
#  '만난': 1,
#  '양쪽': 1,
#  '저리': 1,
#  '한국': 1,
#  '방송': 1,
#  '출연': 1,
#  '적': 1,
#  '래퍼': 1,
#  '바디': 1,
#  '힙색하': 1,
#  '오직': 1,
#  '배달': 1,
#  '부들': 1,
#  '보관': 1,
#  '제품': 1,
#  '쪽': 1,
#  '겨냥': 1,
#  '발매': 1,
#  '코디': 1,
#  '처음': 1,
#  '호불호': 1,
#  '무조건': 1,
#  '생': 1,
#  '악세사리': 1,
#  '무작정': 1,
#  '무시': 1,
#  '베스트': 1,
#  '베레모': 1,
#  '재작년': 1,
#  '세레': 1,
#  '쿼츠': 1,
#  '너리': 1,
#  '스테이': 1,
#  '트먼트': 1,
#  '주얼리': 1,
#  '링': 1,
#  '크기': 1,
#  '피카': 1,
#  '부': 1,
#  '싸이': 1,
#  '옆': 1,
#  '튿': 1,
#  '어진': 1,
#  '타지': 1,
#  '중': 1,
#  '절대': 1,
#  '패셔너블': 1,
#  '길거리': 1,
#  '어쩌면': 1,
#  '일지': 1,
#  '신지': 1,
#  '발레': 1,
#  '누구': 1,
#  '만약': 1,
#  '여러': 1,
#  '보시': 1,
#  '곰돌이': 1,
#  '변신': 1,
#  '테디': 1,
#  '인조': 1,
#  '모피': 1,
#  '덤': 1,
#  '골덴': 1,
#  '코듀로이': 1,
#  '다시': 1,
#  '직장': 1,
#  '퇴근': 1,
#  '후': 1,
#  '간의': 1,
#  '관통': 1,
#  '추구': 1,
#  '핵심': 1,
#  '정반대': 1,
#  '정통': 1,
#  '흐름': 1,
#  '해외': 1,
#  '주요': 1,
#  '언론': 1,
#  '지목': 1,
#  '지난해': 1,
#  '티비': 1,
#  '아담': 1,
#  '셀': 1,
#  '클래식': 1,
#  '선': 1,
#  '아주': 1,
#  '온라인': 1,
#  '공유': 1,
#  '갈비뼈': 1,
#  '탈색': 1,
#  '보석': 1,
#  '발망': 1,
#  '각각': 1,
#  '지지': 1,
#  '하디드': 1,
#  '파파라치': 1,
#  '컷': 1,
#  '공개': 1,
#  '관심': 1,
#  '프랑스': 1,
#  '베트멍': 1,
#  '리바이스': 1,
#  '이름': 1,
#  '전면': 1,
#  '광택': 1,
#  '바탕': 1,
#  '연두색': 1,
#  '뱀': 1,
#  '그림': 1,
#  '바지': 1,
#  '에이치': 1,
#  '앤': 1,
#  '앰': 1,
#  '자라': 1,
#  '화장품': 1,
#  '점퍼': 1,
#  '매니큐어': 1,
#  '대거': 1,
#  '이외': 1,
#  '만': 1,
#  '월스트리트저널': 1,
#  '세기': 1,
#  '혁신': 1,
#  '아이콘': 1,
#  '애용': 1,
#  '조사': 1,
#  '다니엘': 1,
#  '코': 1,
#  '면서': 1,
#  '질': 1,
#  '샌더': 1,
#  '벨루': 1,
#  '생산': 1,
#  '상품': 1,
#  '라벨': 1,
#  '실크': 1,
#  '캐시미어': 1,
#  '아이러니': 1,
#  '셈': 1,
#  '뉴발란스': 1,
#  '회색': 1,
#  '토대': 1,
#  '상상': 1,
#  '숱': 1,
#  '구현': 1,
#  '막대': 1,
#  '팔레': 1,
#  '늘': 1,
#  '베뉴': 1,
#  '둔갑': 1,
#  '메인': 1,
#  '암석': 1,
#  '폭포': 1,
#  '돌체': 1,
#  '앨리스': 1,
#  '장면': 1,
#  '포커': 1,
#  '모래': 1,
#  '산': 1,
#  '오토바이': 1,
#  '라이더': 1,
#  '동산': 1,
#  '펜티': 1,
#  '푸마': 1,
#  '만화가': 1,
#  '명과': 1,
#  '벽화': 1,
#  '은빛': 1,
#  '가루': 1,
#  '루프': 1,
#  '동원': 1,
#  '패션쇼': 1,
#  '어른': 1,
#  '놀이동산': 1,
#  '안이': 1,
#  '훤히': 1,
#  '안야': 1,
#  '힌드': 1,
#  '키치': 1,
#  '폭도': 1,
#  '무척': 1,
#  '천차만별': 1,
#  '취향': 1,
#  '비닐': 1,
#  '당신': 1,
#  '몫': 1,
#  '아이스크림': 1,
#  '머리': 1,
#  '발끝': 1,
#  '빅토리아': 1,
#  '베컴': 1,
#  '블록': 1,
#  '아크네': 1,
#  '등등': 1,
#  '긍정': 1,
#  '소식': 1,
#  '특정': 1,
#  '꼽': 1,
#  '패치': 1,
#  '굽이': 1,
#  '메리제인': 1,
#  '슈즈': 1,
#  '디올': 1,
#  '섹시': 1,
#  '디바': 1,
#  '파워': 1,
#  '숄더': 1,
#  '포드': 1,
#  '물': 1,
#  '스텔라': 1,
#  '절개': 1,
#  '트랜스': 1,
#  '폼': 1,
#  '목걸이': 1,
#  '웨스턴': 1,
#  '계절': 1,
#  '렌즈': 1,
#  '올여름': 1,
#  '침실': 1,
#  '너': 1,
#  '활약': 1,
#  '부실': 1,
#  '지경': 1,
#  '여자': 1,
#  '파자마': 1,
#  '파티': 1,
#  '꼬': 1,
#  '겹': 1,
#  '관능': 1,
#  '오스카': 1,
#  '드': 1,
#  '렌타': 1,
#  '스팽글': 1,
#  '환상': 1,
#  '런가': 1,
#  '계속': 1,
#  '다만': 1,
#  '고루': 1,
#  '취급': 1,
#  '대하': 1,
#  '자세': 1,
#  '사뭇': 1,
#  '갈리아': 1,
#  '노': 1,
#  '트렌치코트': 1,
#  '생활화': 1,
#  '생로': 1,
#  '구름': 1,
#  '타고': 1,
#  '재임': 1,
#  '입증': 1,
#  '마법': 1,
#  '헤어': 1,
#  '분야': 1,
#  '감': 1,
#  '발': 1,
#  '조물': 1,
#  '아티스': 1,
#  '비밀': 1,
#  '정원': 1,
#  '테': 1,
#  '안개꽃': 1,
#  '불어': 1,
#  '꽃다발': 1,
#  '크레이지': 1,
#  '무엇': 1,
#  '하든': 1,
#  '반복': 1,
#  '루이': 1,
#  '비통': 1,
#  '줄무늬': 1,
#  '자': 1,
#  '도전': 1,
#  '스포': 1,
#  '다양성': 1,
#  '서도': 1,
#  '보지': 1,
#  '활개': 1,
#  '굽': 1,
#  '장': 1,
#  '마리': 1,
#  '란주': 1,
#  '버클': 1,
#  '마크': 1,
#  '제이콥': 1,
#  '록스': 1,
#  '로봇': 1,
#  '투': 1,
#  '고무': 1,
#  '서로': 1,
#  '스터드': 1,
#  '뭔가': 1,
#  '과장': 1,
#  '글래머': 1,
#  '러스': 1,
#  '발맹': 1,
#  '에스': 1,
#  '스포티즘': 1,
#  '접근': 1,
#  '몬세': 1,
#  '아이디어': 1,
#  '로에베': 1,
#  '미슬': 1,
#  '인상': 1,
#  '향유': 1,
#  '일로': 1,
#  '때': 1,
#  '아트': 1,
#  '피스': 1,
#  '룩들': 1,
#  '먼저': 1,
#  '우주': 1,
#  '행성': 1,
#  '브라운': 1,
#  '최대한': 1,
#  '로맨틱': 1,
#  '상자': 1,
#  '구멍': 1,
#  '숭숭': 1,
#  '포장': 1,
#  '비비안': 1,
#  '웨스트우드': 1,
#  '이불': 1,
#  '레이': 1,
#  '와쿠': 1,
#  '오타쿠': 1,
#  '구조': 1,
#  '시간': 1,
#  '선물': 1,
#  '덕': 1,
#  '장만': 1,
#  '크러시': 1,
#  '니시': 1,
#  '레드': 1,
#  '연한': 1,
#  '장미': 1,
#  '흰색': 1,
#  '뮤트': 1,
#  '로즈': 1,
#  '겨울': 1,
#  '기존': 1,
#  '어': 1,
#  '두운': 1,
#  '끌': 1,
#  '형광': 1,
#  '옐로': 1,
#  '오렌지': 1,
#  '센스': 1,
#  '지브라': 1,
#  '레오파드': 1,
#  '파이톤': 1,
#  '동물': 1,
#  '니트': 1,
#  '풀': 1,
#  '전체': 1,
#  '야성': 1,
#  '로베르토': 1,
#  '발리': 1,
#  '활동': 1,
#  '그룹': 1,
#  '뮤직비디오': 1,
#  '달': 1,
#  '화제': 1,
#  '타이트': 1,
#  '레깅스': 1,
#  '소화': 1,
#  '기하학': 1,
#  '여러가지': 1,
#  '메': 1,
#  '급부': 1,
#  '중이': 1,
#  '레이어': 1,
#  '드하': 1,
#  '사카이': 1,
#  '베르사체': 1,
#  '글로벌': 1,
#  '다소': 1,
#  '좌우': 1,
#  '지배': 1,
#  '단어': 1,
#  '회고': 1,
#  '추억': 1,
#  '영어': 1,
#  '영화': 1,
#  '콘텐츠': 1,
#  '범람': 1,
#  '영역': 1,
#  '자연': 1,
#  '연초': 1,
#  '평창동계올림픽': 1,
#  '개최': 1,
#  '일명': 1,
#  '일본어': 1,
#  '토파': 1,
#  '밑': 1,
#  '주로': 1,
#  '컽': 1,
#  '일부': 1,
#  '방언': 1,
#  '외투': 1,
#  '불경기': 1,
#  '여파': 1,
#  '타인': 1,
#  '역': 1,
#  '발상': 1,
#  '초점': 1,
#  '장신구': 1,
#  '발산': 1,
#  '조깅': 1,
#  '신고': 1,
#  '전대': 1,
#  '옷차림': 1,
#  '체육복': 1,
#  '반짝': 1,
#  '물방울': 1,
#  '역사': 1,
#  '폴로': 1,
#  '랄프': 1,
#  '로렌': 1,
#  '외국': 1,
#  '직구도': 1,
#  '콜라보': 1,
#  '창': 1,
#  '사무엘': 1,
#  '로스': 1,
#  '포화': 1,
#  '상태': 1,
#  '도달': 1,
#  '길': 1,
#  '시한': 1,
#  '갈등': 1,
#  '주변': 1,
#  '풍경': 1,
#  '그림자': 1,
#  '현실': 1,
#  '인지': 1,
#  '데뷔': 1,
#  '소위': 1,
#  '히어로': 1,
#  '김': 1,
#  '노동자': 1,
#  '복합': 1,
#  '위치': 1,
#  '선점함': 1,
#  '모순': 1,
#  '고급': 1,
#  '편집': 1,
#  '매장': 1,
#  '벽': 1,
#  '한쪽': 1,
#  '차지': 1,
#  '은유': 1,
#  '거의': 1,
#  '모든': 1,
#  '특유': 1,
#  '아트워크': 1,
#  '콜라주': 1,
#  '포함': 1,
#  '그래픽': 1,
#  '손': 1,
#  '염색': 1,
#  '직접': 1,
#  '마감': 1,
#  '디테': 1,
#  '일이': 1,
#  '팔레트': 1,
#  '대신': 1,
#  '앞서': 1,
#  '언어': 1,
#  '뒷받침': 1,
#  '인스타그램': 1,
#  '망': 1,
#  '서비스': 1,
#  '겉': 1,
#  '중시': 1,
#  '좇는': 1,
#  '함몰': 1,
#  '모티브': 1,
#  '설명': 1,
#  '스니커즈': 1,
#  '리치': 1,
#  '키드': 1,
#  '고객': 1,
#  '지지자': 1,
#  '자처': 1,
#  '에어': 1,
#  '프레스토': 1,
#  '에어포스원': 1,
#  '시리즈': 1,
#  '은': 1,
#  '베를린': 1,
#  '기반': 1,
#  '선두': 1,
#  '크리에이티브': 1,
#  '디렉터': 1,
#  '초': 1,
#  '제공': 1,
#  '라인': 1,
#  '명맥': 1,
#  '지휘': 1,
#  '랩': 1,
#  '컨디션': 1,
#  '기어': 1,
#  '지퍼': 1,
#  '스트랩': 1,
#  '부자': 1,
#  '세심': 1,
#  '재단': 1,
#  '마무리': 1,
#  '과정': 1,
#  '최적화': 1,
#  '고스': 1,
#  '다크': 1,
#  '장르': 1,
#  '접점': 1,
#  '고가': 1,
#  '경향': 1,
#  '편협': 1,
#  '겉보기': 1,
#  '특징': 1,
#  '순간': 1,
#  '휘발': 1,
#  '중심': 1,
#  '역설': 1,
#  '돌파': 1,
#  '갓': 1,
#  '흥미': 1,
#  '들보': 1,
#  '전문가': 1,
#  '평가': 1,
#  '유스': 1,
#  '컬처': 1,
#  '자국': 1,
#  '핸드': 1,
#  '메이드': 1,
#  '기법': 1,
#  '전통': 1,
#  '혼합': 1,
#  '지향': 1,
#  '마지막': 1,
#  '퍼즐': 1,
#  '스노': 1,
#  '비어': 1,
#  '인터뷰': 1,
#  '기사': 1,
#  '사랑': 1,
#  '본격': 1,
#  '계기': 1,
#  '거대': 1,
#  '기업': 1,
#  '주관': 1,
#  '최종': 1,
#  '인': 1,
#  '만들기': 1,
#  '아블': 1,
#  '프로젝트': 1,
#  '전파': 1,
#  '상징': 1,
#  '인물': 1,
#  '점': 1,
#  '남성': 1,
#  '유니섹스': 1,
#  '금속': 1,
#  '벨트': 1,
#  '잠금장치': 1,
#  '방': 1,
#  '정성': 1,
#  '세공': 1,
#  '라프': 1,
#  '시몬': 1,
#  '청소년': 1,
#  '헬': 1,
#  '무트': 1,
#  '최소': 1,
#  '주의': 1,
#  '펑크': 1,
#  '레이브': 1,
#  '뒷골목': 1,
#  '클럽': 1,
#  '라이프': 1,
#  '퇴폐': 1,
#  '움': 1,
#  '안': 1,
#  '스킨헤드': 1,
#  '캘리포니아': 1,
#  '배경': 1,
#  '정도': 1,
#  '사진가': 1,
#  '노부': 1,
#  '요시': 1,
#  ...}

# %%
from wordcloud import WordCloud 

import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
# %matplotlib inline

import matplotlib
from IPython.display import set_matplotlib_formats
matplotlib.rc('font',family = 'Malgun Gothic')

set_matplotlib_formats('retina')

matplotlib.rc('axes',unicode_minus = False)

# %%
wordcloud = WordCloud(font_path = 'C:/Windows/Fonts/malgun.ttf', background_color='white',colormap = "Accent_r", width=1500, height=1000).generate_from_frequencies(words) 
plt.rcParams["figure.figsize"] = (20, 20)
plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()
